# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
#  ## Todos los datos
#
# A continuación, se muestra la curva de aprendizaje de todos los datos recopilados, tanto antes como después del descongelado de la red Resnet50

# %%
binary_curve = np.array([
    [0, 0.578784, 0.566258, 0.787105, 0.703146, 0.212895, 0.555981, 0.503903],
    [1, 0.498182, 0.539312, 0.797842, 0.685649, 0.202158, 0.488995, 0.531876],
    [2, 0.485793, 0.484682, 0.804059, 0.693431, 0.195941, 0.499522, 0.548031],
    [3, 0.415009, 0.484728, 0.804829, 0.702612, 0.195171, 0.523445, 0.547685],
    [4, 0.383387, 0.453476, 0.809864, 0.713118, 0.190136, 0.543541, 0.558918],
    [5, 0.363023, 0.457304, 0.809145, 0.718483, 0.190855, 0.559569, 0.555186],
    [6, 0.357179, 0.397529, 0.817775, 0.714940, 0.182225, 0.534689, 0.582486],
    [7, 0.354083, 0.508208, 0.816799, 0.687813, 0.183201, 0.461722, 0.594578],
    [8, 0.346845, 0.384132, 0.826971, 0.706109, 0.173029, 0.494258, 0.622289],
    [9, 0.340733, 0.407079, 0.818957, 0.713868, 0.181043, 0.529665, 0.586957],
    [10, 0.317707, 0.384341, 0.828410, 0.712065, 0.171590, 0.508134, 0.623239],
    [11, 0.317837, 0.390137, 0.823118, 0.715387, 0.176882, 0.526555, 0.600546]])

# %%
train_loss = binary_curve[:, 1]
valid_loss = binary_curve[:, 2]
plt.title("Binary classification total (Resnet50)")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.show()

# %%
binary_curve_unfreeze = np.array([
    [1, 0.329386, 0.425944, 0.823684, 0.716703, 0.176316, 0.529187, 0.601741],
    [2, 0.312175, 0.388174, 0.826252, 0.719729, 0.173748, 0.533014, 0.609076],
    [3, 0.316786, 0.426099, 0.819933, 0.721528, 0.180067, 0.549043, 0.586207]
])

# %%
train_loss = binary_curve_unfreeze[:, 1]
valid_loss = binary_curve_unfreeze[:, 2]
plt.title("Binary classification total (Resnet50)")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.show()

# %%
"""
                precision    recall  f1-score   support

      Benign       0.86      0.93      0.89     15285
   Malignant       0.64      0.46      0.54      4180

    accuracy                           0.83     19465
   macro avg       0.75      0.70      0.72     19465
weighted avg       0.81      0.83      0.82     19465
"""
# Out:
# '\n                precision    recall  f1-score   support\n\n      Benign       0.86      0.93      0.89     15285\n   Malignant       0.64      0.46      0.54      4180\n\n    accuracy                           0.83     19465\n   macro avg       0.75      0.70      0.72     19465\nweighted avg       0.81      0.83      0.82     19465\n'

# %% [markdown]
# ## ISIC
#
# Entrenamientos realizados con únicamente ISIC
# ### Binaria Resnet50

# %%
## Resnet50 ISIC binary
binary_curve = np.array([[0,0.469955,0.423857,0.798345,0.714828,0.201655,0.544715,0.617796],
                        [1,0.378131,0.397805,0.800310,0.751886,0.199690,0.653252,0.598733],
                        [2,0.359175,0.388458,0.805898,0.755768,0.194102,0.653659,0.610942],
                        [3,0.336294,0.395008,0.812933,0.744959,0.187067,0.606504,0.639794],
                        [4,0.338565,0.385340,0.816037,0.740214,0.183963,0.585772,0.655000],
                        [5,0.349646,0.385091,0.814692,0.763674,0.185308,0.659756,0.629802],
                        [6,0.314186,0.373401,0.821004,0.747427,0.178996,0.597561,0.665158],
                        [7,0.310643,0.365790,0.826694,0.756197,0.173306,0.612602,0.676088],
                        [8,0.304161,0.360440,0.818727,0.773876,0.181273,0.682520,0.633585],
                        [9,0.316876,0.356703,0.827522,0.767326,0.172478,0.644715,0.666667],
                        [10,0.314594,0.355996,0.825453,0.747868,0.174547,0.589837,0.681541],
                        [11,0.310809,0.359900,0.830936,0.769884,0.169064,0.645528,0.675745],
                        [12,0.314948,0.359419,0.828970,0.785164,0.171029,0.695935,0.654184]])

# %%
train_loss = binary_curve[:, 1]
valid_loss = binary_curve[:, 2]

# %%
plt.title("Binary classification ISIC (Resnet50)")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.savefig("bin_class_resnetfreeze.png",dpi=200)
plt.show()

# %%
binary_curve_unfreeze = np.array([
    [0,0.295524,0.352863,0.831350,0.755036,0.168650,0.599593,0.695755],
    [1,0.300161,0.377335,0.824211,0.762964,0.175789,0.638211,0.659941],
    [2,0.317536,0.365701,0.826280,0.773722,0.173720,0.666667,0.656263],
    [3,0.328846,0.442817,0.819865,0.764199,0.180135,0.650813,0.644785]])

# %%
train_loss = binary_curve_unfreeze[:, 1]
valid_loss = binary_curve_unfreeze[:, 2]
plt.title("Binary classification ISIC unfreeze(Resnet50)")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.savefig("bin_class_resnetunfreeze.png",dpi=200)
plt.show()

# %% [markdown]
# ### Binaria Efficient net

# %%
binary_efficient_curve = np.array([[0, 0.768764, 1.328998, 0.764718, 0.722526, 0.235282, 0.636585, 0.531568],
                                   [1, 0.671795, 2.507978, 0.781997, 0.737863, 0.218003, 0.647967, 0.562257],
                                   [2, 0.644943, 37.502346, 0.790998, 0.729444, 0.209002, 0.604065, 0.586888],
                                   [3, 0.592931, 0.515688, 0.784584, 0.760346, 0.215416, 0.710976, 0.560577],
                                   [4, 0.614338, 0.479502, 0.793482, 0.756007, 0.206518, 0.679675, 0.580556],
                                   [5, 0.602198, 0.474263, 0.796689, 0.747583, 0.203311, 0.647561, 0.591973],
                                   [6, 0.567670, 44.141792, 0.804552, 0.766377, 0.195447, 0.688618, 0.601349],
                                   [7, 0.567190, 0.446227, 0.806932, 0.760879, 0.193068, 0.667073, 0.610491],
                                   [8, 0.528676, 47.361706, 0.801759, 0.776550, 0.198241, 0.725203, 0.589947],
                                   [9, 0.520491, 0.502386, 0.814796, 0.775924, 0.185204, 0.696748, 0.621465],
                                   [10, 0.535297, 28.754055, 0.818003, 0.762013, 0.181997, 0.647967, 0.640933]])

# %%
train_loss = binary_efficient_curve[:, 1]
valid_loss = binary_efficient_curve[:, 2]

plt.title("Binary classification ISIC (Efficient Net Freeze)")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.savefig("bin_class_efnetfreeze.png",dpi=200)
plt.show()

# %%
binary_efficient_curve_unfreeze = np.array([[0, 0.545518, 0.438375, 0.805898, 0.765405, 0.194102, 0.682927, 0.605187],
                                            [1, 0.579226, 0.488032, 0.808898, 0.760725, 0.191102, 0.662602, 0.615791],
                                            [2, 0.529671, 0.415785, 0.817900, 0.768770, 0.182100, 0.668699, 0.635135],
                                            [3, 0.503017, 5.230848, 0.820693, 0.765156, 0.179307, 0.652033, 0.646514],
                                            [4, 0.411264, 1.021004, 0.817175, 0.781135, 0.182825, 0.707724, 0.624238],
                                            [5, 0.406282, 0.388948, 0.823176, 0.781545, 0.176824, 0.696748, 0.640269],
                                            [6, 0.363866, 0.382578, 0.823383, 0.801227, 0.176617, 0.756098, 0.626896],
                                            [7, 0.325226, 0.355396, 0.835075, 0.766770, 0.164925, 0.627642, 0.694869],
                                            [8, 0.309518, 0.336426, 0.847284, 0.790085, 0.152716, 0.673577, 0.711159],
                                            [9, 0.299320, 0.334027, 0.848733, 0.794001, 0.151267, 0.682520, 0.711441],
                                            [10, 0.284627, 0.351737, 0.837041, 0.820159, 0.162959, 0.785772, 0.648440],
                                            [11, 0.293866, 0.334921, 0.845525, 0.807110, 0.154475, 0.728862, 0.684612],
                                            [12, 0.262016, 0.323905, 0.854630, 0.804248, 0.145370, 0.701626, 0.720067],
                                            [13, 0.264460, 0.321616, 0.854423, 0.812408, 0.145577, 0.726829, 0.708680],
                                            [14, 0.262372, 0.315713, 0.855975, 0.790292, 0.144025, 0.656504, 0.746994],
                                            [15, 0.263222, 0.314125, 0.859493, 0.789439, 0.140507, 0.646748, 0.764904],
                                            [16, 0.247766, 0.321191, 0.856286, 0.816870, 0.143714, 0.736585, 0.709753],
                                            [17, 0.250711, 0.317489, 0.855354, 0.814773, 0.144646, 0.732114, 0.709055],
                                            [18, 0.241912, 0.316964, 0.858045, 0.818184, 0.141956, 0.736992, 0.714342]])

# %%
train_loss = binary_efficient_curve_unfreeze[:, 1]
valid_loss = binary_efficient_curve_unfreeze[:, 2]

plt.title("Binary classification ISIC unfreeze (Efficient Net UnFreeze)")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.savefig("bin_class_efnetunfreeze.png",dpi=200)
plt.show()

# %%
import seaborn as sns
objects = ('EfficientNet B5', 'Resnet50', 'MobilenetV2')
y_pos = np.arange(len(objects))


import numpy as np 
import matplotlib.pyplot as plt 

# set width of bar 
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8)) 

# set height of bar 
orig = [571.71, 1078.465, 574.86]
quant = [361.76, 684.56, 368.87] 

# Set position of bar on X axis 
br1 = np.arange(len(orig)) 
br2 = [x + barWidth for x in br1] 

# Make the plot
plt.bar(br1, orig, width = barWidth, 
         label ='Modelo sin optimizar', color = 'orange') 
plt.bar(br2, quant,  width = barWidth, 
         label ='Modelo cuantizado', color = "steelblue") 

# Adding Xticks 
plt.xlabel('Modelo') 
plt.ylabel('Valor') 
plt.xticks([r + barWidth for r in range(len(orig))], 
        ['EfficientNet B5', 'Resnet50', 'MobileNetV2'])

plt.legend()
plt.savefig("metricas.png",dpi=200)

plt.show()

# %%
flops = [118.5, 103.6, 24.5]
barWidth = 0.25

plt.bar(range(0,3), flops, width = barWidth * 2, color = ['orange', 'steelblue', 'lightblue']
) 
plt.xlabel('Modelo') 
plt.ylabel('Tamaño estimado (MB)') 

for i in range(len(flops)):
        plt.text(i, flops[i], flops[i], ha = 'center')

plt.xticks([r for r in range(len(flops))], 
        ['EfficientNet B5', 'Resnet50', 'MobileNetV2'])
plt.savefig("tamestimado.png",dpi=200)
plt.show()

# %%
"""
precision    recall  f1-score   support

0               0.89      0.93      0.91      7205
1               0.76      0.65      0.70      2460

accuracy                            0.86      9665
macro avg       0.83      0.79      0.80      9665
weighted avg    0.85      0.86      0.86      9665
"""
# Out:
# '\nprecision    recall  f1-score   support\n\n0               0.89      0.93      0.91      7205\n1               0.76      0.65      0.70      2460\n\naccuracy                            0.86      9665\nmacro avg       0.83      0.79      0.80      9665\nweighted avg    0.85      0.86      0.86      9665\n'

# %% [markdown]
# ### Subclases malignas

# %%
malignant_curve = np.array([[0, 1.096714, 0.632065, 0.607564, 0.556164, 0.392436, 0.607564, 0.695006],
                            [1, 0.950529, 0.497443, 0.685645, 0.582984, 0.314355, 0.685645, 0.700459],
                            [2, 0.835745, 0.444383, 0.702725, 0.576808, 0.297275, 0.702725, 0.702055],
                            [3, 0.714720, 0.492004, 0.705571, 0.566045, 0.294429, 0.705571, 0.715414],
                            [4, 0.694405, 0.362215, 0.735665, 0.577413, 0.264335, 0.735665, 0.716952],
                            [5, 0.594322, 0.373642, 0.730378, 0.559720, 0.269622, 0.730378, 0.702830],
                            [6, 0.541629, 0.300663, 0.740138, 0.583544, 0.259862, 0.740138, 0.719419],
                            [7, 0.493053, 0.309082, 0.751932, 0.600534, 0.248068, 0.751932, 0.733715],
                            [8, 0.444510, 0.300841, 0.751932, 0.593406, 0.248068, 0.751932, 0.730749],
                            [9, 0.408266, 0.265712, 0.752338, 0.586596, 0.247662, 0.752338, 0.731362],
                            [10, 0.376519, 0.254161, 0.744612, 0.632503, 0.255388, 0.744612, 0.745553],
                            [11, 0.334873, 0.272853, 0.750305, 0.619394, 0.249695, 0.750305, 0.740873],
                            [12, 0.322356, 0.253828, 0.766978, 0.631350, 0.233022, 0.766978, 0.759422],
                            [13, 0.294407, 0.256145, 0.749898, 0.593202, 0.250102, 0.749898, 0.741659],
                            [14, 0.290699, 0.245140, 0.752338, 0.626171, 0.247662, 0.752338, 0.753093],
                            [15, 0.278616, 0.215149, 0.786499, 0.645817, 0.213501, 0.786499, 0.776862],
                            [16, 0.265446, 0.223911, 0.784465, 0.640258, 0.215535, 0.784465, 0.772979],
                            [17, 0.252687, 0.213947, 0.785279, 0.629282, 0.214721, 0.785279, 0.772995],
                            [18, 0.261795, 0.211540, 0.793819, 0.639267, 0.206181, 0.793819, 0.785842],
                            [19, 0.253370, 0.216651, 0.797072, 0.668575, 0.202928, 0.797072, 0.785749],
                            [20, 0.258422, 0.210675, 0.792599, 0.614790, 0.207401, 0.792599, 0.778127],
                            [21, 0.259699, 0.200757, 0.801545, 0.665122, 0.198455, 0.801545, 0.789275],
                            [22, 0.238750, 0.197447, 0.804799, 0.645781, 0.195201, 0.804799, 0.798535],
                            [23, 0.248048, 0.197003, 0.794632, 0.654739, 0.205368, 0.794632, 0.787713],
                            [24, 0.236761, 0.192910, 0.812119, 0.714749, 0.187881, 0.812119, 0.807359],
                            [25, 0.240587, 0.199618, 0.791379, 0.697871, 0.208621, 0.791379, 0.798913],
                            [26, 0.229578, 0.185953, 0.822285, 0.689060, 0.177715, 0.822285, 0.812790],
                            [27, 0.234178, 0.184471, 0.822692, 0.715286, 0.177308, 0.822692, 0.818507],
                            [28, 0.226533, 0.189337, 0.818219, 0.706954, 0.181781, 0.818219, 0.810940],
                            [29, 0.216192, 0.179382, 0.823099, 0.742113, 0.176901, 0.823099, 0.826383],
                            [30, 0.222893, 0.176481, 0.822692, 0.730927, 0.177308, 0.822692, 0.827919],
                            [31, 0.218217, 0.186161, 0.811305, 0.757908, 0.188695, 0.811305, 0.831262],
                            [32, 0.208700, 0.187077, 0.812932, 0.698408, 0.187068, 0.812932, 0.809493],
                            [33, 0.208461, 0.195977, 0.811712, 0.699305, 0.188288, 0.811712, 0.809772]])

# %%
train_loss = malignant_curve[:, 1]
valid_loss = malignant_curve[:, 2]

# %%
plt.title("Malignant subclass classification")
plt.plot(train_loss)
plt.plot(valid_loss)
plt.legend(["train", "valid"])
plt.show()

# %%
"""
            precision    recall  f1-score   support

0               0.81      0.85      0.83       908
1               0.88      0.92      0.90      1311
2               0.66      0.38      0.48       240

accuracy                            0.84      2459
macro avg       0.79      0.72      0.74      2459
weighted avg    0.84      0.84      0.84      2459
"""
# Out:
# '\n            precision    recall  f1-score   support\n\n0               0.81      0.85      0.83       908\n1               0.88      0.92      0.90      1311\n2               0.66      0.38      0.48       240\n\naccuracy                            0.84      2459\nmacro avg       0.79      0.72      0.74      2459\nweighted avg    0.84      0.84      0.84      2459\n'
