# %%
# %pip install -Uqq fastbook
# %pip install nbdev
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nbdev in c:\users\cris1\anaconda3\lib\site-packages (2.3.13)
# Requirement already satisfied: ipywidgets<=8.0.4 in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (7.8.1)
# Requirement already satisfied: fastcore>=1.5.27 in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (1.5.29)
# Requirement already satisfied: execnb>=0.1.4 in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (0.1.5)
# Requirement already satisfied: astunparse in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (1.6.3)
# Requirement already satisfied: ghapi>=1.0.3 in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (1.0.4)
# Requirement already satisfied: watchdog in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (2.1.6)
# Requirement already satisfied: asttokens in c:\users\cris1\appdata\roaming\python\python311\site-packages (from nbdev) (2.4.1)
# Requirement already satisfied: PyYAML in c:\users\cris1\anaconda3\lib\site-packages (from nbdev) (6.0)
# Requirement already satisfied: ipython in c:\users\cris1\appdata\roaming\python\python311\site-packages (from execnb>=0.1.4->nbdev) (8.18.1)
# Requirement already satisfied: pip in c:\users\cris1\anaconda3\lib\site-packages (from fastcore>=1.5.27->nbdev) (23.2.1)
# Requirement already satisfied: packaging in c:\users\cris1\appdata\roaming\python\python311\site-packages (from fastcore>=1.5.27->nbdev) (23.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipywidgets<=8.0.4->nbdev) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\cris1\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\cris1\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\cris1\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\cris1\anaconda3\lib\site-packages (from ipywidgets<=8.0.4->nbdev) (1.1.7)
# Requirement already satisfied: six>=1.12.0 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from asttokens->nbdev) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\cris1\anaconda3\lib\site-packages (from astunparse->nbdev) (0.38.4)
# Requirement already satisfied: decorator in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.6.3)
# Requirement already satisfied: colorama in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipython->execnb>=0.1.4->nbdev) (0.4.6)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\cris1\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev) (0.8.3)
# Requirement already satisfied: jinja2 in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (6.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (25.1.2)
# Requirement already satisfied: argon2-cffi in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (5.5.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (8.6.0)
# Requirement already satisfied: nbformat in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.5.8)
# Requirement already satisfied: ipykernel in c:\users\cris1\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (6.27.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\cris1\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.5.5)
# Requirement already satisfied: wcwidth in c:\users\cris1\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->execnb>=0.1.4->nbdev) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (2.0.1)
# Requirement already satisfied: pure-eval in c:\users\cris1\appdata\roaming\python\python311\site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (0.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (4.1.0)
# Requirement already satisfied: pywin32>=300 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (306)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\cris1\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\cris1\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.2.2)
# Requirement already satisfied: lxml in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (4.12.2)
# Requirement already satisfied: bleach in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\cris1\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\cris1\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\cris1\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (4.20.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\cris1\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\cris1\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.8.0)
# Requirement already satisfied: psutil in c:\users\cris1\appdata\roaming\python\python311\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (5.9.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\cris1\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cris1\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cris1\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cris1\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.16.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\cris1\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (3.7.1)
# Requirement already satisfied: websocket-client in c:\users\cris1\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\cris1\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cris1\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2.4)
# Requirement already satisfied: webencodings in c:\users\cris1\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\cris1\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cris1\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\cris1\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<=8.0.4->nbdev) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# SET UP Fastai
import fastbook
fastbook.setup_book()
from sklearn.metrics import balanced_accuracy_score
import fastai
import fastcore
print(f'fastcore version {fastcore.__version__} installed')
print(f'fastai version {fastai.__version__} installed')
from nbdev.showdoc import *
from fastai.vision.all import *
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import csv
import cv2
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import MiniBatchKMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
# Out:
# fastcore version 1.5.29 installed
# fastai version 2.7.13 installed

# %%
# Function to display evaluation metrics

@patch
@delegates(subplots)
def plot_metrics(self: Recorder, nrows=None, ncols=None, figsize=None, **kwargs):
    metrics = np.stack(self.values)
    names = self.metric_names[1:-1]
    n = len(names) - 1
    if nrows is None and ncols is None:
        nrows = int(math.sqrt(n))
        ncols = int(np.ceil(n / nrows))
    elif nrows is None: nrows = int(np.ceil(n / ncols))
    elif ncols is None: ncols = int(np.ceil(n / nrows))
    figsize = figsize or (ncols * 6, nrows * 4)
    fig, axs = subplots(nrows, ncols, figsize=figsize, **kwargs)
    axs = [ax if i < n else ax.set_axis_off() for i, ax in enumerate(axs.flatten())][:n]
    for i, (name, ax) in enumerate(zip(names, [axs[0]] + axs)):
        ax.plot(metrics[:, i], color='#1f77b4' if i == 0 else '#ff7f0e', label='valid' if i > 0 else 'train')
        ax.set_title(name if i > 1 else 'losses')
        ax.legend(loc='best')
    plt.show()

# %%
'''
This function receives a string with the filename of the image to read,
and a flag indicating if we want to read it in color/RGB (flagColor=1) or gray level (flagColor=0)

Example of use:
im1=readIm(get_image('apple.jpg'),0)

'''
def readIm(filename, flagColor=1):
  # cv2 reads BGR format
  im=cv2.imread(filename)
  # change to  RGB and return the image
  if(flagColor):
    return cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
  # change from BGR to grayscale instead if flag is 0
  return cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
'''
This function receives an array of arbitrary real numbers (that could include even negative values),
and returns an 'image' in the range [0,1].
flag_GLOBAL allows the user to normalize the whole image (including all channels) or to normalize
each channel/band independently.
'''
def rangeDisplay01(im, flag_GLOBAL= True):
  im = im.astype(float)
  if flag_GLOBAL:
    im = (im - im.min())/(im.max() - im.min())
  else:
    # bands normalization
    for band in range(im.shape[2]):
      im[:, :, band] = (im[:, :, band] - im[:, :, band].min())/(im[:, :, band].max() - im[:, :, band].min())
      # Note: remember that, for plt.imshow with RGB data, the valid range is [0..1] for floats and [0..255] for integers.
  return im

'''
This function displays a single image, including a title, using a magnification factor.

Example of use:
im1=readIm(get_image('apple.jpg'),0)
displayIm(im1,'Manzana',0.5)

'''
def displayIm(im, title='Result',factor= 2):
  # First normalize range
  max=np.max(im)
  min=np.min(im)
  if min<0 or max>255:
    im=rangeDisplay01(im,flag_GLOBAL=True)
  if len(im.shape) == 3:
    # im es tribanda
    plt.imshow(im, cmap='jet')
  else:
    # im es monobanda
    plt.imshow(im, cmap='gray')
  figure_size = plt.gcf().get_size_inches()
  plt.gcf().set_size_inches(factor * figure_size)
  plt.title(title)
  plt.xticks([]), plt.yticks([]) # eliminamos numeración
  plt.show()

# This function display the KeyPoints of an image
def showKP(im,kp,title):
    im_orig = im.copy()
    for curKey in kp:
            x=np.int(curKey.pt[0])
            y=np.int(curKey.pt[1])
            size = np.int(curKey.size)
            cv2.circle(im,(x,y),40,color=(255,0,0), thickness=4) 
    displayIm(im, title)

# %%
# Preprocesar dataFrame en busca de las etiquetas en thumbnails
def get_thumbnails(df_original, img_path):
    filas_seleccionadas = []
    
    for index, fila in df_original.iterrows():

        imagen = fila['image']
        nombre_archivo = img_path + str(imagen)

        # Verificar si el archivo existe en el directorio
        if os.path.exists(nombre_archivo):
            # Si el archivo existe, añadir la fila completa al DataFrame final
            filas_seleccionadas.append(fila)
            
    return filas_seleccionadas

# %%
img_path = "cropped/"
# CSV sin preprocesar
df_original = pd.read_csv('ASAN_TrainingSet.csv')
# .csv procesado
filas = get_thumbnails(df_original, img_path)
train = pd.DataFrame(filas, columns=df_original.columns)
display(train)
# Out:
#                          image            label
# 0              biopsy#ak_0.png        biopsy#ak
# 1              biopsy#ak_1.png        biopsy#ak
# 2              biopsy#ak_2.png        biopsy#ak
# 3              biopsy#ak_3.png        biopsy#ak
# 4              biopsy#ak_4.png        biopsy#ak
# ...                        ...              ...
# 15403  non-biopsy#wart_888.png  non-biopsy#wart
# 15404  non-biopsy#wart_889.png  non-biopsy#wart
# 15405  non-biopsy#wart_890.png  non-biopsy#wart
# 15406  non-biopsy#wart_891.png  non-biopsy#wart
# 15407  non-biopsy#wart_892.png  non-biopsy#wart
#
# [15408 rows x 2 columns]

# %%
LABELS = ['b-AK','b-BCC','b-dermatofibroma','b-Hemangioma','b-intrapitelialCarcinoma','b-Lentigo','b-Melanoma','b-Nevus','b-pyogenincGranuloma','b-SCC','b-SebK','b-Wart', 'AK','Dermatofibroma','Hemangioma','Lentigo','Nevus','PyogenicGranuloma','SebK','Wart']

# %%
# Extraemos el conteo de cada clase
plt.figure(figsize=(12,6))

train_y = np.array(list(train.iloc[:,1]))
#print(train_y)

unique_values, counts = np.unique(train_y, return_counts=True)


# Representamos en un gráfico de barras
sns.barplot(x=LABELS, y=counts, hue = LABELS,dodge=False)
plt.title("Distribución del conjunto de entrenamiento")
plt.tight_layout()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Metadatos

# %%
def label_func(fname):
    #print(str(fname)[8:])
    #print(train.loc[train.image == str(fname)[8:], 'label'].values[0])
    return train.loc[train.image == str(fname)[8:], 'label'].values[0]

# %%
# División en 90% train y 10% validación
trainSet = DataBlock(
    blocks = (ImageBlock, CategoryBlock), # La entrada es un bloque de imagenes, y la salida, categorias
    get_items= get_image_files, # Utilizamos el mñetodo get_image_files proporcionado en el Notebook
    splitter = RandomSplitter(valid_pct = 0.2, seed = 0), # Establecida semilla 0
    get_y = label_func,   # Las etiquetas son especificadas como contenido del dataset en si
    item_tfms = [Resize(224, method='squish')],  # Redimensionado
).dataloaders("cropped/", bs=32)


trainSet.show_batch() # shows a batch of images

# %%
import timm
mobilenet = [model for model in timm.list_models(pretrained = True) if model.startswith('mobile')]
mobilenet
# Out:
# ['mobilenetv2_050.lamb_in1k',
#  'mobilenetv2_100.ra_in1k',
#  'mobilenetv2_110d.ra_in1k',
#  'mobilenetv2_120d.ra_in1k',
#  'mobilenetv2_140.ra_in1k',
#  'mobilenetv3_large_100.miil_in21k',
#  'mobilenetv3_large_100.miil_in21k_ft_in1k',
#  'mobilenetv3_large_100.ra_in1k',
#  'mobilenetv3_rw.rmsp_in1k',
#  'mobilenetv3_small_050.lamb_in1k',
#  'mobilenetv3_small_075.lamb_in1k',
#  'mobilenetv3_small_100.lamb_in1k',
#  'mobileone_s0.apple_in1k',
#  'mobileone_s1.apple_in1k',
#  'mobileone_s2.apple_in1k',
#  'mobileone_s3.apple_in1k',
#  'mobileone_s4.apple_in1k',
#  'mobilevit_s.cvnets_in1k',
#  'mobilevit_xs.cvnets_in1k',
#  'mobilevit_xxs.cvnets_in1k',
#  'mobilevitv2_050.cvnets_in1k',
#  'mobilevitv2_075.cvnets_in1k',
#  'mobilevitv2_100.cvnets_in1k',
#  'mobilevitv2_125.cvnets_in1k',
#  'mobilevitv2_150.cvnets_in1k',
#  'mobilevitv2_150.cvnets_in22k_ft_in1k',
#  'mobilevitv2_150.cvnets_in22k_ft_in1k_384',
#  'mobilevitv2_175.cvnets_in1k',
#  'mobilevitv2_175.cvnets_in22k_ft_in1k',
#  'mobilevitv2_175.cvnets_in22k_ft_in1k_384',
#  'mobilevitv2_200.cvnets_in1k',
#  'mobilevitv2_200.cvnets_in22k_ft_in1k',
#  'mobilevitv2_200.cvnets_in22k_ft_in1k_384']

# %%
resnet_learner_fine = vision_learner(trainSet, 'mobilenetv2_120d.ra_in1k', loss_func=FocalLossFlat(), metrics=[accuracy,error_rate])
resnet_learner_fine.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Sequential (Input shape: 32 x 3 x 224 x 224)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 32 x 112 x 112
# Conv2d                                    864        False
# Identity
# ReLU6
# Conv2d                                    288        False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 24 x 112 x 112
# Conv2d                                    768        False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 144 x 112 x 11
# Conv2d                                    3456       False
# Identity
# ReLU6
# ____________________________________________________________________________
#                      32 x 144 x 56 x 56
# Conv2d                                    1296       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 32 x 56 x 56
# Conv2d                                    4608       False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 56 x 56
# Conv2d                                    6144       False
# Identity
# ReLU6
# Conv2d                                    1728       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 32 x 56 x 56
# Conv2d                                    6144       False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 56 x 56
# Conv2d                                    6144       False
# Identity
# ReLU6
# Conv2d                                    1728       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 32 x 56 x 56
# Conv2d                                    6144       False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 56 x 56
# Conv2d                                    6144       False
# Identity
# ReLU6
# ____________________________________________________________________________
#                      32 x 192 x 28 x 28
# Conv2d                                    1728       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    7680       False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       False
# Identity
# ReLU6
# Conv2d                                    2160       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    9600       False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       False
# Identity
# ReLU6
# Conv2d                                    2160       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    9600       False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       False
# Identity
# ReLU6
# Conv2d                                    2160       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    9600       False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       False
# Identity
# ReLU6
# Conv2d                                    2160       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    9600       False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       False
# Identity
# ReLU6
# ____________________________________________________________________________
#                      32 x 240 x 14 x 14
# Conv2d                                    2160       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    19200      False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      False
# Identity
# ReLU6
# Conv2d                                    4320       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    38400      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      False
# Identity
# ReLU6
# Conv2d                                    4320       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    38400      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      False
# Identity
# ReLU6
# Conv2d                                    4320       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    38400      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      False
# Identity
# ReLU6
# Conv2d                                    4320       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    38400      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      False
# Identity
# ReLU6
# Conv2d                                    4320       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    38400      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      False
# Identity
# ReLU6
# Conv2d                                    4320       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    53760      False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      False
# Identity
# ReLU6
# Conv2d                                    6048       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    75264      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      False
# Identity
# ReLU6
# Conv2d                                    6048       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    75264      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      False
# Identity
# ReLU6
# Conv2d                                    6048       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    75264      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      False
# Identity
# ReLU6
# Conv2d                                    6048       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    75264      False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      False
# Identity
# ReLU6
# ____________________________________________________________________________
#                      32 x 672 x 7 x 7
# Conv2d                                    6048       False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 7 x 7
# Conv2d                                    129024     False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 1152 x 7 x 7
# Conv2d                                    221184     False
# Identity
# ReLU6
# Conv2d                                    10368      False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 7 x 7
# Conv2d                                    221184     False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 1152 x 7 x 7
# Conv2d                                    221184     False
# Identity
# ReLU6
# Conv2d                                    10368      False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 7 x 7
# Conv2d                                    221184     False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 1152 x 7 x 7
# Conv2d                                    221184     False
# Identity
# ReLU6
# Conv2d                                    10368      False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 7 x 7
# Conv2d                                    221184     False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 1152 x 7 x 7
# Conv2d                                    221184     False
# Identity
# ReLU6
# Conv2d                                    10368      False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 192 x 7 x 7
# Conv2d                                    221184     False
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 1152 x 7 x 7
# Conv2d                                    221184     False
# Identity
# ReLU6
# Conv2d                                    10368      False
# Identity
# ReLU6
# Identity
# ____________________________________________________________________________
#                      32 x 384 x 7 x 7
# Conv2d                                    442368     False
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 1280 x 7 x 7
# Conv2d                                    491520     False
# Identity
# ReLU6
# ____________________________________________________________________________
#                      32 x 1280 x 1 x 1
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# ____________________________________________________________________________
#                      32 x 2560
# Flatten
# BatchNorm1d                               5120       True
# Dropout
# ____________________________________________________________________________
#                      32 x 512
# Linear                                    1310720    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      32 x 20
# Linear                                    10240      True
# ____________________________________________________________________________
#
# Total params: 5,813,472
# Total trainable params: 1,327,104
# Total non-trainable params: 4,486,368
#
# Optimizer used: <function Adam at 0x000002BB01D776A0>
# Loss function: FlattenedLoss of FocalLoss()
#
# Model frozen up to parameter group #1
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
resnet_learner_fine.fine_tune(epochs = 4, freeze_epochs= 8)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.523223</td>
#       <td>1.682966</td>
#       <td>0.427783</td>
#       <td>0.572217</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.914965</td>
#       <td>1.443233</td>
#       <td>0.475170</td>
#       <td>0.524830</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.667251</td>
#       <td>1.303911</td>
#       <td>0.497566</td>
#       <td>0.502434</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.373138</td>
#       <td>1.192379</td>
#       <td>0.515742</td>
#       <td>0.484258</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.236592</td>
#       <td>1.128965</td>
#       <td>0.518987</td>
#       <td>0.481013</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.168332</td>
#       <td>1.100124</td>
#       <td>0.518014</td>
#       <td>0.481986</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.103567</td>
#       <td>1.033680</td>
#       <td>0.560532</td>
#       <td>0.439468</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.061514</td>
#       <td>1.023778</td>
#       <td>0.550795</td>
#       <td>0.449205</td>
#       <td>01:02</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.806935</td>
#       <td>0.940676</td>
#       <td>0.582278</td>
#       <td>0.417722</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.723749</td>
#       <td>0.906256</td>
#       <td>0.591366</td>
#       <td>0.408634</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.617154</td>
#       <td>0.863137</td>
#       <td>0.605972</td>
#       <td>0.394028</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.547570</td>
#       <td>0.870521</td>
#       <td>0.602726</td>
#       <td>0.397274</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
resnet_learner_fine.recorder.plot_metrics() #Muestra las pérdidas, el accuracy y la tasa de error

# %%
# We compute the confusion matrix
interp = ClassificationInterpretation.from_learner(resnet_learner_fine,1, trainSet.train)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
probs, _ = resnet_learner_fine.get_preds(dl=trainSet.train)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
cm = interp.confusion_matrix()
print('Number of test examples:', np.sum(cm))
interp.plot_confusion_matrix(figsize=(12, 12),title='Confusion Matrix for the Train Set')
print('Train Accuracy')
train_acc = np.sum(np.diagonal(cm))/np.sum(cm)*100
print(train_acc)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Number of test examples: 12327
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Train Accuracy
# 88.40756063924718

# %%
cm = interp.confusion_matrix()
interp = ClassificationInterpretation.from_learner(resnet_learner_fine,1, trainSet.valid)
print('Number of valid examples:', np.sum(cm))
interp.plot_confusion_matrix(figsize=(12, 12),title='Confusion Matrix for the Validation Set')
print('Valid Accuracy')
test_acc = np.sum(np.diagonal(cm))/np.sum(cm)*100
print(test_acc)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Number of valid examples: 12327
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Valid Accuracy
# 88.40756063924718
