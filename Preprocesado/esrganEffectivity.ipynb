# %% [markdown]
# # Comprobación de efectividad de ESRGAN sobre las imágenes
#
# En este anexo, estudiaremos el impacto real de usar una GAN de super resolución haciendo uso de la partición de validación, comparando si se trata de una mejora significativa o NO. Para ello, tomaremos ASAN, el dataset reescalado mediante este mecanismo.

# %%
# Librerías utilizadas por el script
import os
import cv2
import zipfile
import csv
import pathlib
import shutil

import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from copy import deepcopy
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
# Function to display evaluation metrics
# Developed by Ignacio Oguiza: https://forums.fasst.ai/t/plotting-metrics-after-learning/69937

import fastbook

fastbook.setup_book()
import fastai
import fastcore

print(f'fastcore version {fastcore.__version__} installed')
print(f'fastai version {fastai.__version__} installed')
from nbdev.showdoc import *
from fastai.vision.all import *


@patch
@delegates(subplots)
def plot_metrics(self: Recorder, nrows=None, ncols=None, figsize=None, **kwargs):
    metrics = np.stack(self.values)
    names = self.metric_names[1:-1]
    n = len(names) - 1
    if nrows is None and ncols is None:
        nrows = int(math.sqrt(n))
        ncols = int(np.ceil(n / nrows))
    elif nrows is None:
        nrows = int(np.ceil(n / ncols))
    elif ncols is None:
        ncols = int(np.ceil(n / nrows))
    figsize = figsize or (ncols * 6, nrows * 4)
    fig, axs = subplots(nrows, ncols, figsize=figsize, **kwargs)
    axs = [ax if i < n else ax.set_axis_off() for i, ax in enumerate(axs.flatten())][:n]
    for i, (name, ax) in enumerate(zip(names, [axs[0]] + axs)):
        ax.plot(metrics[:, i], color='#1f77b4' if i == 0 else '#ff7f0e', label='valid' if i > 0 else 'train')
        ax.set_title(name if i > 1 else 'losses')
        ax.legend(loc='best')
    plt.show()
# Out:
# fastcore version 1.5.29 installed
# fastai version 2.7.14 installed

# %% [markdown]
# Importamos el modelo a utilizar, mobilenetv3.

# %%
from fastai.vision.all import *
import timm

mobilenet3 = timm.create_model('mobilenetv3_large_100', pretrained=True)
mobilenet3.eval()
# Out:
# MobileNetV3(
#   (conv_stem): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): Hardswish()
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#         (bn2): BatchNormAct2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#         (bn2): BatchNormAct2d(
#           72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#         (bn2): BatchNormAct2d(
#           72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         (bn2): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         (bn2): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (bn2): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#         (bn2): BatchNormAct2d(
#           200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#         (bn2): BatchNormAct2d(
#           184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#         (bn2): BatchNormAct2d(
#           184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (act1): ReLU(inplace=True)
#           (conv_expand): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Hardsigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): ConvBnAct(
#         (conv): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Hardswish()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Identity())
#   (conv_head): Conv2d(960, 1280, kernel_size=(1, 1), stride=(1, 1))
#   (act2): Hardswish()
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (classifier): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %% [markdown]
# ## Imágenes reescaladas
# A continuación, estudiamos la efectivdad separando solo las fotos reescaladas.

# %%
def label_func(fname):
    el = df.loc[df['image'] == str(fname).split("\\")[-1]]
    return ((el['class'].values[0]))

# %%
# Obtenemos ASAN
# División en 80% train y 20% validación

df = pd.read_csv('trainSet.csv')

trainSet = DataBlock(
    blocks=(ImageBlock, CategoryBlock),  # La entrada es un bloque de imagenes, y la salida, categorias
    get_items=get_image_files,  # Utilizamos el mñetodo get_image_files proporcionado en el Notebook
    splitter=RandomSplitter(valid_pct=0.2, seed=0),  # Establecida semilla 0
    get_y=label_func,  # Las etiquetas son especificadas como contenido del dataset en si
    item_tfms=[Resize(224, method='squish')],  # Redimensionado
).dataloaders("ESRGAN/test/", bs=32)

# %%
trainSet.show_batch()  # shows a batch of images

# %%
mobilenet_learner = Learner(trainSet, mobilenet3, loss_func=FocalLoss(), metrics=[accuracy, error_rate])
mobilenet_learner.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# MobileNetV3 (Input shape: 32 x 3 x 224 x 224)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 16 x 112 x 112
# Conv2d                                    432        True
# Identity
# Hardswish
# Conv2d                                    144        True
# Identity
# ReLU
# Identity
# Conv2d                                    256        True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 64 x 112 x 112
# Conv2d                                    1024       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 64 x 56 x 56
# Conv2d                                    576        True
# Identity
# ReLU
# Identity
# ____________________________________________________________________________
#                      32 x 24 x 56 x 56
# Conv2d                                    1536       True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 72 x 56 x 56
# Conv2d                                    1728       True
# Identity
# ReLU
# Conv2d                                    648        True
# Identity
# ReLU
# Identity
# ____________________________________________________________________________
#                      32 x 24 x 56 x 56
# Conv2d                                    1728       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 72 x 56 x 56
# Conv2d                                    1728       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 72 x 28 x 28
# Conv2d                                    1800       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 24 x 1 x 1
# Conv2d                                    1752       True
# ReLU
# ____________________________________________________________________________
#                      32 x 72 x 1 x 1
# Conv2d                                    1800       True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    2880       True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 120 x 28 x 28
# Conv2d                                    4800       True
# Identity
# ReLU
# Conv2d                                    3000       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 32 x 1 x 1
# Conv2d                                    3872       True
# ReLU
# ____________________________________________________________________________
#                      32 x 120 x 1 x 1
# Conv2d                                    3960       True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    4800       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 120 x 28 x 28
# Conv2d                                    4800       True
# Identity
# ReLU
# Conv2d                                    3000       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 32 x 1 x 1
# Conv2d                                    3872       True
# ReLU
# ____________________________________________________________________________
#                      32 x 120 x 1 x 1
# Conv2d                                    3960       True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    4800       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 240 x 14 x 14
# Conv2d                                    2160       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    19200      True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 200 x 14 x 14
# Conv2d                                    16000      True
# Identity
# Hardswish
# Conv2d                                    1800       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    16000      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 184 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Hardswish
# Conv2d                                    1656       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 184 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Hardswish
# Conv2d                                    1656       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      True
# Identity
# Hardswish
# Conv2d                                    4320       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 120 x 1 x 1
# Conv2d                                    57720      True
# ReLU
# ____________________________________________________________________________
#                      32 x 480 x 1 x 1
# Conv2d                                    58080      True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    53760      True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Hardswish
# Conv2d                                    6048       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 168 x 1 x 1
# Conv2d                                    113064     True
# ReLU
# ____________________________________________________________________________
#                      32 x 672 x 1 x 1
# Conv2d                                    113568     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 672 x 7 x 7
# Conv2d                                    16800      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 168 x 1 x 1
# Conv2d                                    113064     True
# ReLU
# ____________________________________________________________________________
#                      32 x 672 x 1 x 1
# Conv2d                                    113568     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 160 x 7 x 7
# Conv2d                                    107520     True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# Conv2d                                    24000      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 240 x 1 x 1
# Conv2d                                    230640     True
# ReLU
# ____________________________________________________________________________
#                      32 x 960 x 1 x 1
# Conv2d                                    231360     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 160 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# Conv2d                                    24000      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 240 x 1 x 1
# Conv2d                                    230640     True
# ReLU
# ____________________________________________________________________________
#                      32 x 960 x 1 x 1
# Conv2d                                    231360     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 160 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 960 x 1 x 1
# AdaptiveAvgPool2d
# Identity
# ____________________________________________________________________________
#                      32 x 1280 x 1 x 1
# Conv2d                                    1230080    True
# Hardswish
# ____________________________________________________________________________
#                      32 x 1280
# Flatten
# ____________________________________________________________________________
#                      32 x 1000
# Linear                                    1281000    True
# ____________________________________________________________________________
#
# Total params: 5,458,632
# Total trainable params: 5,458,632
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001EDE3004CC0>
# Loss function: FocalLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
lrs = mobilenet_learner.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# Entrena las capas superiores
mobilenet_learner.fine_tune(epochs=5, base_lr=lrs[0])

# %%
mobilenet_learner.recorder.plot_metrics()  #Muestra las pérdidas, el accuracy y la tasa de error

# %%
# Descongela todas las capas
mobilenet_learner.unfreeze()

# Encuentrar nuevo lr
lrs = mobilenet_learner.lr_find()

mobilenet_learner.fine_tune(epochs=10, base_lr=lrs[0])

# %%
interp = ClassificationInterpretation.from_learner(mobilenet_learner, 1, trainSet.valid)

preds, targets = mobilenet_learner.get_preds(ds_idx=1)  # ds_idx=1 para el conjunto de validación

y_true = targets.numpy()
y_pred = preds.argmax(dim=1).numpy()  # Convierte las probabilidades en etiquetas predichas

# %%
balanced_acc = balanced_accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"Balanced accuracy: {balanced_acc * 100:.4f}")
print(f"Precision: {prec * 100:.4f}")
print(f"F1 Score: {f1 * 100:.4f}")
# Out:
# Balanced accuracy: 69.3878
# Precision: 73.7520
# F1 Score: 73.5409

# %% [markdown]
# Ahora, podemos ver la tasa de aciertos y precisión por cada clase clasificada:

# %%
from sklearn.metrics import classification_report

y_true = targets.numpy()
y_pred = preds.argmax(dim=1).numpy()  # Convierte las probabilidades en etiquetas predichas

report = classification_report(y_true, y_pred,target_names=trainSet.vocab)
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#         actinic_keratosis       0.65      0.60      0.62        92
#      basal_cell_carcinoma       0.73      0.72      0.72       130
#            dermatofibroma       0.89      0.73      0.80       168
#                hemangioma       0.83      0.85      0.84       292
# intraepithelial_carcinoma       0.60      0.53      0.56       110
#               lentigo_nos       0.79      0.75      0.77       138
#                  melanoma       0.76      0.66      0.70        67
#                     nevus       0.75      0.81      0.78       325
#        pyogenic_granuloma       0.68      0.64      0.66        36
#       seborreic_keratosis       0.62      0.61      0.61       166
#   squamous_cell_carcinoma       0.64      0.63      0.63       145
#                      wart       0.73      0.82      0.77       333
#
#                  accuracy                           0.74      2002
#                 macro avg       0.72      0.69      0.71      2002
#              weighted avg       0.74      0.74      0.74      2002

# %% [markdown]
# ## Imágenes originales
# Ahora, realizaremos el mismos experimento, pero sin ampliar las imágenes

# %%
def label_func(fname):
    el = df.loc[df['image'] == str(fname).split("\\")[-1]]
    return ((el['class'].values[0]))

# %%
"""# Ruta de la carpeta con los archivos
datos = pd.read_csv('trainSet.csv')


ruta_carpeta = r"ESRGAN\LR\wart_lr"

# Lee el DataFrame (ajusta la ruta según tu caso)

# Itera a través de los archivos en la carpeta
for archivo in os.listdir(ruta_carpeta):
    if archivo not in datos['image'].tolist():
        # Elimina el archivo si su nombre no está en el DataFrame
        os.remove(os.path.join(ruta_carpeta, archivo))
        print(f"Archivo eliminado: {archivo}")

print("Proceso completado.")"""
# Out:
# Archivo eliminado: ASAN_10000.png
# Archivo eliminado: ASAN_10002.png
# Archivo eliminado: ASAN_10003.png
# Archivo eliminado: ASAN_10004.png
# Archivo eliminado: ASAN_10007.png
# Archivo eliminado: ASAN_10011.png
# Archivo eliminado: ASAN_10012.png
# Archivo eliminado: ASAN_10014.png
# Archivo eliminado: ASAN_10015.png
# Archivo eliminado: ASAN_10019.png
# Archivo eliminado: ASAN_10026.png
# Archivo eliminado: ASAN_10028.png
# Archivo eliminado: ASAN_10032.png
# Archivo eliminado: ASAN_10033.png
# Archivo eliminado: ASAN_10035.png
# Archivo eliminado: ASAN_10039.png
# Archivo eliminado: ASAN_10046.png
# Archivo eliminado: ASAN_10049.png
# Archivo eliminado: ASAN_10050.png
# Archivo eliminado: ASAN_10053.png
# Archivo eliminado: ASAN_10059.png
# Archivo eliminado: ASAN_10062.png
# Archivo eliminado: ASAN_10065.png
# Archivo eliminado: ASAN_10066.png
# Archivo eliminado: ASAN_10068.png
# Archivo eliminado: ASAN_10075.png
# Archivo eliminado: ASAN_10077.png
# Archivo eliminado: ASAN_10078.png
# Archivo eliminado: ASAN_10079.png
# Archivo eliminado: ASAN_10080.png
# Archivo eliminado: ASAN_10083.png
# Archivo eliminado: ASAN_10090.png
# Archivo eliminado: ASAN_10092.png
# Archivo eliminado: ASAN_10094.png
# Archivo eliminado: ASAN_10096.png
# Archivo eliminado: ASAN_10098.png
# Archivo eliminado: ASAN_10100.png
# Archivo eliminado: ASAN_10104.png
# Archivo eliminado: ASAN_10105.png
# Archivo eliminado: ASAN_10112.png
# Archivo eliminado: ASAN_10120.png
# Archivo eliminado: ASAN_10121.png
# Archivo eliminado: ASAN_10123.png
# Archivo eliminado: ASAN_10125.png
# Archivo eliminado: ASAN_10127.png
# Archivo eliminado: ASAN_10128.png
# Archivo eliminado: ASAN_10130.png
# Archivo eliminado: ASAN_10132.png
# Archivo eliminado: ASAN_10134.png
# Archivo eliminado: ASAN_10139.png
# Archivo eliminado: ASAN_10143.png
# Archivo eliminado: ASAN_10146.png
# Archivo eliminado: ASAN_10149.png
# Archivo eliminado: ASAN_10153.png
# Archivo eliminado: ASAN_10155.png
# Archivo eliminado: ASAN_10156.png
# Archivo eliminado: ASAN_10157.png
# Archivo eliminado: ASAN_10164.png
# Archivo eliminado: ASAN_10166.png
# Archivo eliminado: ASAN_10170.png
# Archivo eliminado: ASAN_10171.png
# Archivo eliminado: ASAN_10176.png
# Archivo eliminado: ASAN_10178.png
# Archivo eliminado: ASAN_10179.png
# Archivo eliminado: ASAN_10182.png
# Archivo eliminado: ASAN_10183.png
# Archivo eliminado: ASAN_10184.png
# Archivo eliminado: ASAN_10186.png
# Archivo eliminado: ASAN_10188.png
# Archivo eliminado: ASAN_10192.png
# Archivo eliminado: ASAN_10193.png
# Archivo eliminado: ASAN_10195.png
# Archivo eliminado: ASAN_10196.png
# Archivo eliminado: ASAN_10197.png
# Archivo eliminado: ASAN_10200.png
# Archivo eliminado: ASAN_10201.png
# Archivo eliminado: ASAN_10202.png
# Archivo eliminado: ASAN_10203.png
# Archivo eliminado: ASAN_10204.png
# Archivo eliminado: ASAN_10205.png
# Archivo eliminado: ASAN_10210.png
# Archivo eliminado: ASAN_10212.png
# Archivo eliminado: ASAN_10213.png
# Archivo eliminado: ASAN_10214.png
# Archivo eliminado: ASAN_10216.png
# Archivo eliminado: ASAN_10219.png
# Archivo eliminado: ASAN_10221.png
# Archivo eliminado: ASAN_10222.png
# Archivo eliminado: ASAN_10223.png
# Archivo eliminado: ASAN_10224.png
# Archivo eliminado: ASAN_10226.png
# Archivo eliminado: ASAN_10228.png
# Archivo eliminado: ASAN_10232.png
# Archivo eliminado: ASAN_10234.png
# Archivo eliminado: ASAN_10238.png
# Archivo eliminado: ASAN_10242.png
# Archivo eliminado: ASAN_10243.png
# Archivo eliminado: ASAN_10249.png
# Archivo eliminado: ASAN_10255.png
# Archivo eliminado: ASAN_10260.png
# Archivo eliminado: ASAN_10261.png
# Archivo eliminado: ASAN_10262.png
# Archivo eliminado: ASAN_10263.png
# Archivo eliminado: ASAN_10264.png
# Archivo eliminado: ASAN_10267.png
# Archivo eliminado: ASAN_10268.png
# Archivo eliminado: ASAN_10272.png
# Archivo eliminado: ASAN_10277.png
# Archivo eliminado: ASAN_10280.png
# Archivo eliminado: ASAN_10286.png
# Archivo eliminado: ASAN_10289.png
# Archivo eliminado: ASAN_10292.png
# Archivo eliminado: ASAN_10294.png
# Archivo eliminado: ASAN_10296.png
# Archivo eliminado: ASAN_10298.png
# Archivo eliminado: ASAN_10304.png
# Archivo eliminado: ASAN_10306.png
# Archivo eliminado: ASAN_10311.png
# Archivo eliminado: ASAN_10316.png
# Archivo eliminado: ASAN_10318.png
# Archivo eliminado: ASAN_10325.png
# Archivo eliminado: ASAN_10327.png
# Archivo eliminado: ASAN_10328.png
# Archivo eliminado: ASAN_10332.png
# Archivo eliminado: ASAN_10334.png
# Archivo eliminado: ASAN_10337.png
# Archivo eliminado: ASAN_10338.png
# Archivo eliminado: ASAN_10339.png
# Archivo eliminado: ASAN_10340.png
# Archivo eliminado: ASAN_10342.png
# Archivo eliminado: ASAN_10344.png
# Archivo eliminado: ASAN_10347.png
# Archivo eliminado: ASAN_10352.png
# Archivo eliminado: ASAN_10356.png
# Archivo eliminado: ASAN_10358.png
# Archivo eliminado: ASAN_10363.png
# Archivo eliminado: ASAN_10364.png
# Archivo eliminado: ASAN_10365.png
# Archivo eliminado: ASAN_10366.png
# Archivo eliminado: ASAN_10367.png
# Archivo eliminado: ASAN_10369.png
# Archivo eliminado: ASAN_10370.png
# Archivo eliminado: ASAN_10371.png
# Archivo eliminado: ASAN_10372.png
# Archivo eliminado: ASAN_10374.png
# Archivo eliminado: ASAN_10375.png
# Archivo eliminado: ASAN_10376.png
# Archivo eliminado: ASAN_10379.png
# Archivo eliminado: ASAN_10380.png
# Archivo eliminado: ASAN_10381.png
# Archivo eliminado: ASAN_10382.png
# Archivo eliminado: ASAN_10383.png
# Archivo eliminado: ASAN_10384.png
# Archivo eliminado: ASAN_10387.png
# Archivo eliminado: ASAN_10389.png
# Archivo eliminado: ASAN_10390.png
# Archivo eliminado: ASAN_10391.png
# Archivo eliminado: ASAN_10392.png
# Archivo eliminado: ASAN_10396.png
# Archivo eliminado: ASAN_10397.png
# Archivo eliminado: ASAN_10399.png
# Archivo eliminado: ASAN_10400.png
# Archivo eliminado: ASAN_10407.png
# Archivo eliminado: ASAN_10409.png
# Archivo eliminado: ASAN_10411.png
# Archivo eliminado: ASAN_10412.png
# Archivo eliminado: ASAN_10419.png
# Archivo eliminado: ASAN_10422.png
# Archivo eliminado: ASAN_10423.png
# Archivo eliminado: ASAN_10426.png
# Archivo eliminado: ASAN_10427.png
# Archivo eliminado: ASAN_10429.png
# Archivo eliminado: ASAN_10430.png
# Archivo eliminado: ASAN_10433.png
# Archivo eliminado: ASAN_10438.png
# Archivo eliminado: ASAN_10441.png
# Archivo eliminado: ASAN_10442.png
# Archivo eliminado: ASAN_10447.png
# Archivo eliminado: ASAN_10448.png
# Archivo eliminado: ASAN_10451.png
# Archivo eliminado: ASAN_10457.png
# Archivo eliminado: ASAN_10458.png
# Archivo eliminado: ASAN_10463.png
# Archivo eliminado: ASAN_10465.png
# Archivo eliminado: ASAN_10466.png
# Archivo eliminado: ASAN_10469.png
# Archivo eliminado: ASAN_10472.png
# Archivo eliminado: ASAN_10473.png
# Archivo eliminado: ASAN_10474.png
# Archivo eliminado: ASAN_10475.png
# Archivo eliminado: ASAN_10476.png
# Archivo eliminado: ASAN_10477.png
# Archivo eliminado: ASAN_10478.png
# Archivo eliminado: ASAN_10482.png
# Archivo eliminado: ASAN_10486.png
# Archivo eliminado: ASAN_10490.png
# Archivo eliminado: ASAN_10494.png
# Archivo eliminado: ASAN_10510.png
# Archivo eliminado: ASAN_10511.png
# Archivo eliminado: ASAN_10513.png
# Archivo eliminado: ASAN_10514.png
# Archivo eliminado: ASAN_10515.png
# Archivo eliminado: ASAN_10517.png
# Archivo eliminado: ASAN_10518.png
# Archivo eliminado: ASAN_10520.png
# Archivo eliminado: ASAN_10522.png
# Archivo eliminado: ASAN_10523.png
# Archivo eliminado: ASAN_10524.png
# Archivo eliminado: ASAN_10525.png
# Archivo eliminado: ASAN_10530.png
# Archivo eliminado: ASAN_10533.png
# Archivo eliminado: ASAN_10534.png
# Archivo eliminado: ASAN_10536.png
# Archivo eliminado: ASAN_10537.png
# Archivo eliminado: ASAN_10538.png
# Archivo eliminado: ASAN_10541.png
# Archivo eliminado: ASAN_10544.png
# Archivo eliminado: ASAN_10547.png
# Archivo eliminado: ASAN_10548.png
# Archivo eliminado: ASAN_10551.png
# Archivo eliminado: ASAN_10553.png
# Archivo eliminado: ASAN_10554.png
# Archivo eliminado: ASAN_10556.png
# Archivo eliminado: ASAN_10557.png
# Archivo eliminado: ASAN_10560.png
# Archivo eliminado: ASAN_10569.png
# Archivo eliminado: ASAN_10570.png
# Archivo eliminado: ASAN_10573.png
# Archivo eliminado: ASAN_10575.png
# Archivo eliminado: ASAN_10580.png
# Archivo eliminado: ASAN_10585.png
# Archivo eliminado: ASAN_10587.png
# Archivo eliminado: ASAN_10590.png
# Archivo eliminado: ASAN_10592.png
# Archivo eliminado: ASAN_10595.png
# Archivo eliminado: ASAN_10596.png
# Archivo eliminado: ASAN_10597.png
# Archivo eliminado: ASAN_10599.png
# Archivo eliminado: ASAN_10601.png
# Archivo eliminado: ASAN_10604.png
# Archivo eliminado: ASAN_10608.png
# Archivo eliminado: ASAN_10609.png
# Archivo eliminado: ASAN_10610.png
# Archivo eliminado: ASAN_10611.png
# Archivo eliminado: ASAN_10612.png
# Archivo eliminado: ASAN_10615.png
# Archivo eliminado: ASAN_10617.png
# Archivo eliminado: ASAN_10620.png
# Archivo eliminado: ASAN_10621.png
# Archivo eliminado: ASAN_10622.png
# Archivo eliminado: ASAN_10624.png
# Archivo eliminado: ASAN_10627.png
# Archivo eliminado: ASAN_10630.png
# Archivo eliminado: ASAN_10631.png
# Archivo eliminado: ASAN_10633.png
# Archivo eliminado: ASAN_10634.png
# Archivo eliminado: ASAN_10640.png
# Archivo eliminado: ASAN_10641.png
# Archivo eliminado: ASAN_10643.png
# Archivo eliminado: ASAN_10645.png
# Archivo eliminado: ASAN_10647.png
# Archivo eliminado: ASAN_10648.png
# Archivo eliminado: ASAN_10649.png
# Archivo eliminado: ASAN_10652.png
# Archivo eliminado: ASAN_10655.png
# Archivo eliminado: ASAN_10656.png
# Archivo eliminado: ASAN_10659.png
# Archivo eliminado: ASAN_10661.png
# Archivo eliminado: ASAN_10663.png
# Archivo eliminado: ASAN_10666.png
# Archivo eliminado: ASAN_10671.png
# Archivo eliminado: ASAN_10675.png
# Archivo eliminado: ASAN_10676.png
# Archivo eliminado: ASAN_10679.png
# Archivo eliminado: ASAN_10682.png
# Archivo eliminado: ASAN_10687.png
# Archivo eliminado: ASAN_10689.png
# Archivo eliminado: ASAN_10692.png
# Archivo eliminado: ASAN_10693.png
# Archivo eliminado: ASAN_10694.png
# Archivo eliminado: ASAN_10702.png
# Archivo eliminado: ASAN_10704.png
# Archivo eliminado: ASAN_10709.png
# Archivo eliminado: ASAN_10712.png
# Archivo eliminado: ASAN_10715.png
# Archivo eliminado: ASAN_10720.png
# Archivo eliminado: ASAN_10723.png
# Archivo eliminado: ASAN_10724.png
# Archivo eliminado: ASAN_10725.png
# Archivo eliminado: ASAN_10726.png
# Archivo eliminado: ASAN_10730.png
# Archivo eliminado: ASAN_10734.png
# Archivo eliminado: ASAN_10737.png
# Archivo eliminado: ASAN_10739.png
# Archivo eliminado: ASAN_10740.png
# Archivo eliminado: ASAN_10742.png
# Archivo eliminado: ASAN_10743.png
# Archivo eliminado: ASAN_10745.png
# Archivo eliminado: ASAN_10748.png
# Archivo eliminado: ASAN_10751.png
# Archivo eliminado: ASAN_10754.png
# Archivo eliminado: ASAN_10757.png
# Archivo eliminado: ASAN_10767.png
# Archivo eliminado: ASAN_10769.png
# Archivo eliminado: ASAN_10770.png
# Archivo eliminado: ASAN_10771.png
# Archivo eliminado: ASAN_10773.png
# Archivo eliminado: ASAN_10775.png
# Archivo eliminado: ASAN_10776.png
# Archivo eliminado: ASAN_10782.png
# Archivo eliminado: ASAN_10783.png
# Archivo eliminado: ASAN_10786.png
# Archivo eliminado: ASAN_10788.png
# Archivo eliminado: ASAN_10789.png
# Archivo eliminado: ASAN_10795.png
# Archivo eliminado: ASAN_10797.png
# Archivo eliminado: ASAN_10801.png
# Archivo eliminado: ASAN_10807.png
# Archivo eliminado: ASAN_10809.png
# Archivo eliminado: ASAN_10814.png
# Archivo eliminado: ASAN_10815.png
# Archivo eliminado: ASAN_10818.png
# Archivo eliminado: ASAN_10821.png
# Archivo eliminado: ASAN_10829.png
# Archivo eliminado: ASAN_10830.png
# Archivo eliminado: ASAN_10831.png
# Archivo eliminado: ASAN_10833.png
# Archivo eliminado: ASAN_10834.png
# Archivo eliminado: ASAN_10836.png
# Archivo eliminado: ASAN_10837.png
# Archivo eliminado: ASAN_10838.png
# Archivo eliminado: ASAN_10839.png
# Archivo eliminado: ASAN_10840.png
# Archivo eliminado: ASAN_10842.png
# Archivo eliminado: ASAN_10846.png
# Archivo eliminado: ASAN_10850.png
# Archivo eliminado: ASAN_10854.png
# Archivo eliminado: ASAN_10858.png
# Archivo eliminado: ASAN_10859.png
# Archivo eliminado: ASAN_10860.png
# Archivo eliminado: ASAN_10863.png
# Archivo eliminado: ASAN_10864.png
# Archivo eliminado: ASAN_10867.png
# Archivo eliminado: ASAN_10870.png
# Archivo eliminado: ASAN_10876.png
# Archivo eliminado: ASAN_10877.png
# Archivo eliminado: ASAN_10879.png
# Archivo eliminado: ASAN_10886.png
# Archivo eliminado: ASAN_10887.png
# Archivo eliminado: ASAN_10889.png
# Archivo eliminado: ASAN_10897.png
# Archivo eliminado: ASAN_10900.png
# Archivo eliminado: ASAN_10906.png
# Archivo eliminado: ASAN_10908.png
# Archivo eliminado: ASAN_10910.png
# Archivo eliminado: ASAN_10916.png
# Archivo eliminado: ASAN_10918.png
# Archivo eliminado: ASAN_10919.png
# Archivo eliminado: ASAN_10923.png
# Archivo eliminado: ASAN_10924.png
# Archivo eliminado: ASAN_10925.png
# Archivo eliminado: ASAN_10927.png
# Archivo eliminado: ASAN_10928.png
# Archivo eliminado: ASAN_10930.png
# Archivo eliminado: ASAN_10933.png
# Archivo eliminado: ASAN_10934.png
# Archivo eliminado: ASAN_10937.png
# Archivo eliminado: ASAN_10938.png
# Archivo eliminado: ASAN_10942.png
# Archivo eliminado: ASAN_10944.png
# Archivo eliminado: ASAN_10946.png
# Archivo eliminado: ASAN_10947.png
# Archivo eliminado: ASAN_10956.png
# Archivo eliminado: ASAN_10964.png
# Archivo eliminado: ASAN_10970.png
# Archivo eliminado: ASAN_10974.png
# Archivo eliminado: ASAN_10975.png
# Archivo eliminado: ASAN_10978.png
# Archivo eliminado: ASAN_10980.png
# Archivo eliminado: ASAN_10982.png
# Archivo eliminado: ASAN_10990.png
# Archivo eliminado: ASAN_10995.png
# Archivo eliminado: ASAN_10996.png
# Archivo eliminado: ASAN_11001.png
# Archivo eliminado: ASAN_11003.png
# Archivo eliminado: ASAN_11006.png
# Archivo eliminado: ASAN_11008.png
# Archivo eliminado: ASAN_11009.png
# Archivo eliminado: ASAN_11010.png
# Archivo eliminado: ASAN_11012.png
# Archivo eliminado: ASAN_11014.png
# Archivo eliminado: ASAN_11017.png
# Archivo eliminado: ASAN_11021.png
# Archivo eliminado: ASAN_11022.png
# Archivo eliminado: ASAN_11023.png
# Archivo eliminado: ASAN_11031.png
# Archivo eliminado: ASAN_11032.png
# Archivo eliminado: ASAN_11036.png
# Archivo eliminado: ASAN_11040.png
# Archivo eliminado: ASAN_11042.png
# Archivo eliminado: ASAN_11043.png
# Archivo eliminado: ASAN_11046.png
# Archivo eliminado: ASAN_11048.png
# Archivo eliminado: ASAN_11049.png
# Archivo eliminado: ASAN_11050.png
# Archivo eliminado: ASAN_11051.png
# Archivo eliminado: ASAN_11052.png
# Archivo eliminado: ASAN_11058.png
# Archivo eliminado: ASAN_11062.png
# Archivo eliminado: ASAN_11063.png
# Archivo eliminado: ASAN_11064.png
# Archivo eliminado: ASAN_11066.png
# Archivo eliminado: ASAN_11067.png
# Archivo eliminado: ASAN_11068.png
# Archivo eliminado: ASAN_11073.png
# Archivo eliminado: ASAN_11074.png
# Archivo eliminado: ASAN_11080.png
# Archivo eliminado: ASAN_11081.png
# Archivo eliminado: ASAN_11084.png
# Archivo eliminado: ASAN_11086.png
# Archivo eliminado: ASAN_11088.png
# Archivo eliminado: ASAN_11091.png
# Archivo eliminado: ASAN_11093.png
# Archivo eliminado: ASAN_11094.png
# Archivo eliminado: ASAN_11096.png
# Archivo eliminado: ASAN_11098.png
# Archivo eliminado: ASAN_11100.png
# Archivo eliminado: ASAN_11102.png
# Archivo eliminado: ASAN_11104.png
# Archivo eliminado: ASAN_11105.png
# Archivo eliminado: ASAN_11110.png
# Archivo eliminado: ASAN_11112.png
# Archivo eliminado: ASAN_11115.png
# Archivo eliminado: ASAN_11116.png
# Archivo eliminado: ASAN_11117.png
# Archivo eliminado: ASAN_11118.png
# Archivo eliminado: ASAN_11125.png
# Archivo eliminado: ASAN_11127.png
# Archivo eliminado: ASAN_11129.png
# Archivo eliminado: ASAN_11130.png
# Archivo eliminado: ASAN_11131.png
# Archivo eliminado: ASAN_11132.png
# Archivo eliminado: ASAN_11134.png
# Archivo eliminado: ASAN_11136.png
# Archivo eliminado: ASAN_11139.png
# Archivo eliminado: ASAN_11140.png
# Archivo eliminado: ASAN_11141.png
# Archivo eliminado: ASAN_11142.png
# Archivo eliminado: ASAN_11146.png
# Archivo eliminado: ASAN_11149.png
# Archivo eliminado: ASAN_11153.png
# Archivo eliminado: ASAN_11156.png
# Archivo eliminado: ASAN_11159.png
# Archivo eliminado: ASAN_11160.png
# Archivo eliminado: ASAN_11161.png
# Archivo eliminado: ASAN_11162.png
# Archivo eliminado: ASAN_11167.png
# Archivo eliminado: ASAN_11168.png
# Archivo eliminado: ASAN_11174.png
# Archivo eliminado: ASAN_11175.png
# Archivo eliminado: ASAN_11176.png
# Archivo eliminado: ASAN_11182.png
# Archivo eliminado: ASAN_11187.png
# Archivo eliminado: ASAN_11188.png
# Archivo eliminado: ASAN_11190.png
# Archivo eliminado: ASAN_11193.png
# Archivo eliminado: ASAN_11194.png
# Archivo eliminado: ASAN_11195.png
# Archivo eliminado: ASAN_11196.png
# Archivo eliminado: ASAN_11201.png
# Archivo eliminado: ASAN_11202.png
# Archivo eliminado: ASAN_11205.png
# Archivo eliminado: ASAN_11209.png
# Archivo eliminado: ASAN_11210.png
# Archivo eliminado: ASAN_11212.png
# Archivo eliminado: ASAN_11214.png
# Archivo eliminado: ASAN_11215.png
# Archivo eliminado: ASAN_11216.png
# Archivo eliminado: ASAN_11218.png
# Archivo eliminado: ASAN_11221.png
# Archivo eliminado: ASAN_11222.png
# Archivo eliminado: ASAN_11223.png
# Archivo eliminado: ASAN_11224.png
# Archivo eliminado: ASAN_11230.png
# Archivo eliminado: ASAN_11232.png
# Archivo eliminado: ASAN_11238.png
# Archivo eliminado: ASAN_11239.png
# Archivo eliminado: ASAN_11240.png
# Archivo eliminado: ASAN_11248.png
# Archivo eliminado: ASAN_11253.png
# Archivo eliminado: ASAN_11254.png
# Archivo eliminado: ASAN_11259.png
# Archivo eliminado: ASAN_11261.png
# Archivo eliminado: ASAN_11265.png
# Archivo eliminado: ASAN_11266.png
# Archivo eliminado: ASAN_11269.png
# Archivo eliminado: ASAN_11272.png
# Archivo eliminado: ASAN_11273.png
# Archivo eliminado: ASAN_11274.png
# Archivo eliminado: ASAN_11280.png
# Archivo eliminado: ASAN_11283.png
# Archivo eliminado: ASAN_11285.png
# Archivo eliminado: ASAN_11287.png
# Archivo eliminado: ASAN_11290.png
# Archivo eliminado: ASAN_11293.png
# Archivo eliminado: ASAN_11294.png
# Archivo eliminado: ASAN_11297.png
# Archivo eliminado: ASAN_11298.png
# Archivo eliminado: ASAN_11300.png
# Archivo eliminado: ASAN_11302.png
# Archivo eliminado: ASAN_11303.png
# Archivo eliminado: ASAN_11304.png
# Archivo eliminado: ASAN_11305.png
# Archivo eliminado: ASAN_11309.png
# Archivo eliminado: ASAN_11312.png
# Archivo eliminado: ASAN_11313.png
# Archivo eliminado: ASAN_11314.png
# Archivo eliminado: ASAN_11315.png
# Archivo eliminado: ASAN_11316.png
# Archivo eliminado: ASAN_11317.png
# Archivo eliminado: ASAN_11318.png
# Archivo eliminado: ASAN_11319.png
# Archivo eliminado: ASAN_11322.png
# Archivo eliminado: ASAN_11324.png
# Archivo eliminado: ASAN_11325.png
# Archivo eliminado: ASAN_11327.png
# Archivo eliminado: ASAN_11328.png
# Archivo eliminado: ASAN_11329.png
# Archivo eliminado: ASAN_11330.png
# Archivo eliminado: ASAN_11332.png
# Archivo eliminado: ASAN_11334.png
# Archivo eliminado: ASAN_11335.png
# Archivo eliminado: ASAN_11336.png
# Archivo eliminado: ASAN_11340.png
# Archivo eliminado: ASAN_11341.png
# Archivo eliminado: ASAN_11342.png
# Archivo eliminado: ASAN_11343.png
# Archivo eliminado: ASAN_11344.png
# Archivo eliminado: ASAN_11346.png
# Archivo eliminado: ASAN_11350.png
# Archivo eliminado: ASAN_11355.png
# Archivo eliminado: ASAN_11356.png
# Archivo eliminado: ASAN_11358.png
# Archivo eliminado: ASAN_11359.png
# Archivo eliminado: ASAN_11361.png
# Archivo eliminado: ASAN_11362.png
# Archivo eliminado: ASAN_11363.png
# Archivo eliminado: ASAN_11369.png
# Archivo eliminado: ASAN_11370.png
# Archivo eliminado: ASAN_11371.png
# Archivo eliminado: ASAN_11373.png
# Archivo eliminado: ASAN_11374.png
# Archivo eliminado: ASAN_11375.png
# Archivo eliminado: ASAN_11376.png
# Archivo eliminado: ASAN_14516.png
# Archivo eliminado: ASAN_14517.png
# Archivo eliminado: ASAN_14522.png
# Archivo eliminado: ASAN_14523.png
# Archivo eliminado: ASAN_14525.png
# Archivo eliminado: ASAN_14527.png
# Archivo eliminado: ASAN_14531.png
# Archivo eliminado: ASAN_14532.png
# Archivo eliminado: ASAN_14533.png
# Archivo eliminado: ASAN_14534.png
# Archivo eliminado: ASAN_14537.png
# Archivo eliminado: ASAN_14538.png
# Archivo eliminado: ASAN_14539.png
# Archivo eliminado: ASAN_14542.png
# Archivo eliminado: ASAN_14547.png
# Archivo eliminado: ASAN_14548.png
# Archivo eliminado: ASAN_14549.png
# Archivo eliminado: ASAN_14550.png
# Archivo eliminado: ASAN_14554.png
# Archivo eliminado: ASAN_14557.png
# Archivo eliminado: ASAN_14560.png
# Archivo eliminado: ASAN_14567.png
# Archivo eliminado: ASAN_14571.png
# Archivo eliminado: ASAN_14576.png
# Archivo eliminado: ASAN_14578.png
# Archivo eliminado: ASAN_14580.png
# Archivo eliminado: ASAN_14583.png
# Archivo eliminado: ASAN_14585.png
# Archivo eliminado: ASAN_14586.png
# Archivo eliminado: ASAN_14590.png
# Archivo eliminado: ASAN_14592.png
# Archivo eliminado: ASAN_14593.png
# Archivo eliminado: ASAN_14594.png
# Archivo eliminado: ASAN_14598.png
# Archivo eliminado: ASAN_14599.png
# Archivo eliminado: ASAN_14600.png
# Archivo eliminado: ASAN_14601.png
# Archivo eliminado: ASAN_14602.png
# Archivo eliminado: ASAN_14604.png
# Archivo eliminado: ASAN_14607.png
# Archivo eliminado: ASAN_14610.png
# Archivo eliminado: ASAN_14616.png
# Archivo eliminado: ASAN_14617.png
# Archivo eliminado: ASAN_14618.png
# Archivo eliminado: ASAN_14621.png
# Archivo eliminado: ASAN_14622.png
# Archivo eliminado: ASAN_14623.png
# Archivo eliminado: ASAN_14632.png
# Archivo eliminado: ASAN_14633.png
# Archivo eliminado: ASAN_14634.png
# Archivo eliminado: ASAN_14636.png
# Archivo eliminado: ASAN_14641.png
# Archivo eliminado: ASAN_14646.png
# Archivo eliminado: ASAN_14650.png
# Archivo eliminado: ASAN_14653.png
# Archivo eliminado: ASAN_14654.png
# Archivo eliminado: ASAN_14658.png
# Archivo eliminado: ASAN_14661.png
# Archivo eliminado: ASAN_14662.png
# Archivo eliminado: ASAN_14663.png
# Archivo eliminado: ASAN_14664.png
# Archivo eliminado: ASAN_14665.png
# Archivo eliminado: ASAN_14666.png
# Archivo eliminado: ASAN_14671.png
# Archivo eliminado: ASAN_14672.png
# Archivo eliminado: ASAN_14675.png
# Archivo eliminado: ASAN_14677.png
# Archivo eliminado: ASAN_14679.png
# Archivo eliminado: ASAN_14683.png
# Archivo eliminado: ASAN_14685.png
# Archivo eliminado: ASAN_14686.png
# Archivo eliminado: ASAN_14690.png
# Archivo eliminado: ASAN_14692.png
# Archivo eliminado: ASAN_14696.png
# Archivo eliminado: ASAN_14697.png
# Archivo eliminado: ASAN_14699.png
# Archivo eliminado: ASAN_14700.png
# Archivo eliminado: ASAN_14701.png
# Archivo eliminado: ASAN_14703.png
# Archivo eliminado: ASAN_14704.png
# Archivo eliminado: ASAN_14706.png
# Archivo eliminado: ASAN_14707.png
# Archivo eliminado: ASAN_14709.png
# Archivo eliminado: ASAN_14712.png
# Archivo eliminado: ASAN_14721.png
# Archivo eliminado: ASAN_14722.png
# Archivo eliminado: ASAN_14723.png
# Archivo eliminado: ASAN_14727.png
# Archivo eliminado: ASAN_14731.png
# Archivo eliminado: ASAN_14732.png
# Archivo eliminado: ASAN_14734.png
# Archivo eliminado: ASAN_14735.png
# Archivo eliminado: ASAN_14736.png
# Archivo eliminado: ASAN_14739.png
# Archivo eliminado: ASAN_14740.png
# Archivo eliminado: ASAN_14742.png
# Archivo eliminado: ASAN_14745.png
# Archivo eliminado: ASAN_14746.png
# Archivo eliminado: ASAN_14748.png
# Archivo eliminado: ASAN_14751.png
# Archivo eliminado: ASAN_14752.png
# Archivo eliminado: ASAN_14753.png
# Archivo eliminado: ASAN_14754.png
# Archivo eliminado: ASAN_14760.png
# Archivo eliminado: ASAN_14761.png
# Archivo eliminado: ASAN_14763.png
# Archivo eliminado: ASAN_14771.png
# Archivo eliminado: ASAN_14774.png
# Archivo eliminado: ASAN_14778.png
# Archivo eliminado: ASAN_14785.png
# Archivo eliminado: ASAN_14786.png
# Archivo eliminado: ASAN_14787.png
# Archivo eliminado: ASAN_14789.png
# Archivo eliminado: ASAN_14791.png
# Archivo eliminado: ASAN_14794.png
# Archivo eliminado: ASAN_14796.png
# Archivo eliminado: ASAN_14797.png
# Archivo eliminado: ASAN_14799.png
# Archivo eliminado: ASAN_14800.png
# Archivo eliminado: ASAN_14802.png
# Archivo eliminado: ASAN_14803.png
# Archivo eliminado: ASAN_14804.png
# Archivo eliminado: ASAN_14805.png
# Archivo eliminado: ASAN_14807.png
# Archivo eliminado: ASAN_14810.png
# Archivo eliminado: ASAN_14811.png
# Archivo eliminado: ASAN_14814.png
# Archivo eliminado: ASAN_14816.png
# Archivo eliminado: ASAN_14818.png
# Archivo eliminado: ASAN_14822.png
# Archivo eliminado: ASAN_14823.png
# Archivo eliminado: ASAN_14824.png
# Archivo eliminado: ASAN_14825.png
# Archivo eliminado: ASAN_14828.png
# Archivo eliminado: ASAN_14832.png
# Archivo eliminado: ASAN_14833.png
# Archivo eliminado: ASAN_14837.png
# Archivo eliminado: ASAN_14838.png
# Archivo eliminado: ASAN_14840.png
# Archivo eliminado: ASAN_14847.png
# Archivo eliminado: ASAN_14850.png
# Archivo eliminado: ASAN_14853.png
# Archivo eliminado: ASAN_14854.png
# Archivo eliminado: ASAN_14856.png
# Archivo eliminado: ASAN_14857.png
# Archivo eliminado: ASAN_14859.png
# Archivo eliminado: ASAN_14862.png
# Archivo eliminado: ASAN_14870.png
# Archivo eliminado: ASAN_14878.png
# Archivo eliminado: ASAN_14879.png
# Archivo eliminado: ASAN_14888.png
# Archivo eliminado: ASAN_14890.png
# Archivo eliminado: ASAN_14891.png
# Archivo eliminado: ASAN_14894.png
# Archivo eliminado: ASAN_14901.png
# Archivo eliminado: ASAN_14905.png
# Archivo eliminado: ASAN_14906.png
# Archivo eliminado: ASAN_14907.png
# Archivo eliminado: ASAN_14918.png
# Archivo eliminado: ASAN_14919.png
# Archivo eliminado: ASAN_14922.png
# Archivo eliminado: ASAN_14925.png
# Archivo eliminado: ASAN_14927.png
# Archivo eliminado: ASAN_14935.png
# Archivo eliminado: ASAN_14936.png
# Archivo eliminado: ASAN_14939.png
# Archivo eliminado: ASAN_14941.png
# Archivo eliminado: ASAN_14943.png
# Archivo eliminado: ASAN_14945.png
# Archivo eliminado: ASAN_14949.png
# Archivo eliminado: ASAN_14958.png
# Archivo eliminado: ASAN_14960.png
# Archivo eliminado: ASAN_14961.png
# Archivo eliminado: ASAN_14962.png
# Archivo eliminado: ASAN_14970.png
# Archivo eliminado: ASAN_14971.png
# Archivo eliminado: ASAN_14975.png
# Archivo eliminado: ASAN_14978.png
# Archivo eliminado: ASAN_14982.png
# Archivo eliminado: ASAN_14983.png
# Archivo eliminado: ASAN_14986.png
# Archivo eliminado: ASAN_14988.png
# Archivo eliminado: ASAN_14989.png
# Archivo eliminado: ASAN_14990.png
# Archivo eliminado: ASAN_14995.png
# Archivo eliminado: ASAN_14996.png
# Archivo eliminado: ASAN_14998.png
# Archivo eliminado: ASAN_15000.png
# Archivo eliminado: ASAN_15002.png
# Archivo eliminado: ASAN_15009.png
# Archivo eliminado: ASAN_15013.png
# Archivo eliminado: ASAN_15018.png
# Archivo eliminado: ASAN_15020.png
# Archivo eliminado: ASAN_15023.png
# Archivo eliminado: ASAN_15024.png
# Archivo eliminado: ASAN_15025.png
# Archivo eliminado: ASAN_15037.png
# Archivo eliminado: ASAN_15041.png
# Archivo eliminado: ASAN_15046.png
# Archivo eliminado: ASAN_15048.png
# Archivo eliminado: ASAN_15050.png
# Archivo eliminado: ASAN_15052.png
# Archivo eliminado: ASAN_15053.png
# Archivo eliminado: ASAN_15054.png
# Archivo eliminado: ASAN_15055.png
# Archivo eliminado: ASAN_15056.png
# Archivo eliminado: ASAN_15057.png
# Archivo eliminado: ASAN_15058.png
# Archivo eliminado: ASAN_15063.png
# Archivo eliminado: ASAN_15067.png
# Archivo eliminado: ASAN_15069.png
# Archivo eliminado: ASAN_15070.png
# Archivo eliminado: ASAN_15071.png
# Archivo eliminado: ASAN_15073.png
# Archivo eliminado: ASAN_15074.png
# Archivo eliminado: ASAN_15078.png
# Archivo eliminado: ASAN_15083.png
# Archivo eliminado: ASAN_15084.png
# Archivo eliminado: ASAN_15085.png
# Archivo eliminado: ASAN_15089.png
# Archivo eliminado: ASAN_15093.png
# Archivo eliminado: ASAN_15095.png
# Archivo eliminado: ASAN_15102.png
# Archivo eliminado: ASAN_15105.png
# Archivo eliminado: ASAN_15116.png
# Archivo eliminado: ASAN_15117.png
# Archivo eliminado: ASAN_15119.png
# Archivo eliminado: ASAN_15120.png
# Archivo eliminado: ASAN_15122.png
# Archivo eliminado: ASAN_15123.png
# Archivo eliminado: ASAN_15126.png
# Archivo eliminado: ASAN_15128.png
# Archivo eliminado: ASAN_15129.png
# Archivo eliminado: ASAN_15133.png
# Archivo eliminado: ASAN_15134.png
# Archivo eliminado: ASAN_15136.png
# Archivo eliminado: ASAN_15138.png
# Archivo eliminado: ASAN_15139.png
# Archivo eliminado: ASAN_15140.png
# Archivo eliminado: ASAN_15143.png
# Archivo eliminado: ASAN_15144.png
# Archivo eliminado: ASAN_15147.png
# Archivo eliminado: ASAN_15149.png
# Archivo eliminado: ASAN_15150.png
# Archivo eliminado: ASAN_15151.png
# Archivo eliminado: ASAN_15153.png
# Archivo eliminado: ASAN_15155.png
# Archivo eliminado: ASAN_15157.png
# Archivo eliminado: ASAN_15164.png
# Archivo eliminado: ASAN_15165.png
# Archivo eliminado: ASAN_15166.png
# Archivo eliminado: ASAN_15168.png
# Archivo eliminado: ASAN_15170.png
# Archivo eliminado: ASAN_15173.png
# Archivo eliminado: ASAN_15174.png
# Archivo eliminado: ASAN_15176.png
# Archivo eliminado: ASAN_15178.png
# Archivo eliminado: ASAN_15180.png
# Archivo eliminado: ASAN_15181.png
# Archivo eliminado: ASAN_15182.png
# Archivo eliminado: ASAN_15183.png
# Archivo eliminado: ASAN_15185.png
# Archivo eliminado: ASAN_15189.png
# Archivo eliminado: ASAN_15190.png
# Archivo eliminado: ASAN_15191.png
# Archivo eliminado: ASAN_15192.png
# Archivo eliminado: ASAN_15193.png
# Archivo eliminado: ASAN_15198.png
# Archivo eliminado: ASAN_15202.png
# Archivo eliminado: ASAN_15203.png
# Archivo eliminado: ASAN_15207.png
# Archivo eliminado: ASAN_15211.png
# Archivo eliminado: ASAN_15212.png
# Archivo eliminado: ASAN_15215.png
# Archivo eliminado: ASAN_15219.png
# Archivo eliminado: ASAN_15220.png
# Archivo eliminado: ASAN_15221.png
# Archivo eliminado: ASAN_15226.png
# Archivo eliminado: ASAN_15230.png
# Archivo eliminado: ASAN_15232.png
# Archivo eliminado: ASAN_15233.png
# Archivo eliminado: ASAN_15235.png
# Archivo eliminado: ASAN_15236.png
# Archivo eliminado: ASAN_15237.png
# Archivo eliminado: ASAN_15238.png
# Archivo eliminado: ASAN_15243.png
# Archivo eliminado: ASAN_15245.png
# Archivo eliminado: ASAN_15250.png
# Archivo eliminado: ASAN_15252.png
# Archivo eliminado: ASAN_15261.png
# Archivo eliminado: ASAN_15263.png
# Archivo eliminado: ASAN_15264.png
# Archivo eliminado: ASAN_15267.png
# Archivo eliminado: ASAN_15272.png
# Archivo eliminado: ASAN_15274.png
# Archivo eliminado: ASAN_15278.png
# Archivo eliminado: ASAN_15279.png
# Archivo eliminado: ASAN_15282.png
# Archivo eliminado: ASAN_15286.png
# Archivo eliminado: ASAN_15287.png
# Archivo eliminado: ASAN_15291.png
# Archivo eliminado: ASAN_15293.png
# Archivo eliminado: ASAN_15294.png
# Archivo eliminado: ASAN_15296.png
# Archivo eliminado: ASAN_15297.png
# Archivo eliminado: ASAN_15301.png
# Archivo eliminado: ASAN_15306.png
# Archivo eliminado: ASAN_15308.png
# Archivo eliminado: ASAN_15309.png
# Archivo eliminado: ASAN_15314.png
# Archivo eliminado: ASAN_15319.png
# Archivo eliminado: ASAN_15320.png
# Archivo eliminado: ASAN_15322.png
# Archivo eliminado: ASAN_15324.png
# Archivo eliminado: ASAN_15326.png
# Archivo eliminado: ASAN_15327.png
# Archivo eliminado: ASAN_15328.png
# Archivo eliminado: ASAN_15331.png
# Archivo eliminado: ASAN_15336.png
# Archivo eliminado: ASAN_15337.png
# Archivo eliminado: ASAN_15340.png
# Archivo eliminado: ASAN_15346.png
# Archivo eliminado: ASAN_15347.png
# Archivo eliminado: ASAN_15350.png
# Archivo eliminado: ASAN_15353.png
# Archivo eliminado: ASAN_15357.png
# Archivo eliminado: ASAN_15359.png
# Archivo eliminado: ASAN_15360.png
# Archivo eliminado: ASAN_15361.png
# Archivo eliminado: ASAN_15362.png
# Archivo eliminado: ASAN_15368.png
# Archivo eliminado: ASAN_15369.png
# Archivo eliminado: ASAN_15370.png
# Archivo eliminado: ASAN_15375.png
# Archivo eliminado: ASAN_15376.png
# Archivo eliminado: ASAN_15377.png
# Archivo eliminado: ASAN_15378.png
# Archivo eliminado: ASAN_15382.png
# Archivo eliminado: ASAN_15384.png
# Archivo eliminado: ASAN_15387.png
# Archivo eliminado: ASAN_15389.png
# Archivo eliminado: ASAN_15390.png
# Archivo eliminado: ASAN_15393.png
# Archivo eliminado: ASAN_15395.png
# Archivo eliminado: ASAN_15396.png
# Archivo eliminado: ASAN_15399.png
# Archivo eliminado: ASAN_15401.png
# Archivo eliminado: ASAN_15403.png
# Archivo eliminado: ASAN_15407.png
# Archivo eliminado: ASAN_16487.png
# Archivo eliminado: ASAN_16490.png
# Archivo eliminado: ASAN_16493.png
# Archivo eliminado: ASAN_16495.png
# Archivo eliminado: ASAN_16497.png
# Archivo eliminado: ASAN_16501.png
# Archivo eliminado: ASAN_16503.png
# Archivo eliminado: ASAN_16504.png
# Archivo eliminado: ASAN_16505.png
# Archivo eliminado: ASAN_16506.png
# Archivo eliminado: ASAN_16507.png
# Archivo eliminado: ASAN_16509.png
# Archivo eliminado: ASAN_16512.png
# Archivo eliminado: ASAN_16519.png
# Archivo eliminado: ASAN_16521.png
# Archivo eliminado: ASAN_16522.png
# Archivo eliminado: ASAN_16528.png
# Archivo eliminado: ASAN_16529.png
# Archivo eliminado: ASAN_16535.png
# Archivo eliminado: ASAN_16537.png
# Archivo eliminado: ASAN_16538.png
# Archivo eliminado: ASAN_16539.png
# Archivo eliminado: ASAN_16542.png
# Archivo eliminado: ASAN_16543.png
# Archivo eliminado: ASAN_16546.png
# Archivo eliminado: ASAN_16549.png
# Archivo eliminado: ASAN_16550.png
# Archivo eliminado: ASAN_16551.png
# Archivo eliminado: ASAN_16553.png
# Archivo eliminado: ASAN_16554.png
# Archivo eliminado: ASAN_16556.png
# Archivo eliminado: ASAN_16557.png
# Archivo eliminado: ASAN_16558.png
# Archivo eliminado: ASAN_16563.png
# Archivo eliminado: ASAN_16565.png
# Archivo eliminado: ASAN_16568.png
# Archivo eliminado: ASAN_16575.png
# Archivo eliminado: ASAN_16576.png
# Archivo eliminado: ASAN_16577.png
# Archivo eliminado: ASAN_16578.png
# Archivo eliminado: ASAN_16581.png
# Archivo eliminado: ASAN_16582.png
# Archivo eliminado: ASAN_16586.png
# Archivo eliminado: ASAN_16590.png
# Archivo eliminado: ASAN_16592.png
# Archivo eliminado: ASAN_16594.png
# Archivo eliminado: ASAN_16595.png
# Archivo eliminado: ASAN_16598.png
# Archivo eliminado: ASAN_16602.png
# Archivo eliminado: ASAN_16603.png
# Archivo eliminado: ASAN_16606.png
# Archivo eliminado: ASAN_16609.png
# Archivo eliminado: ASAN_16610.png
# Archivo eliminado: ASAN_16611.png
# Archivo eliminado: ASAN_16615.png
# Archivo eliminado: ASAN_16619.png
# Archivo eliminado: ASAN_16620.png
# Archivo eliminado: ASAN_16622.png
# Archivo eliminado: ASAN_16625.png
# Archivo eliminado: ASAN_16626.png
# Archivo eliminado: ASAN_16627.png
# Archivo eliminado: ASAN_16628.png
# Archivo eliminado: ASAN_16635.png
# Archivo eliminado: ASAN_16636.png
# Archivo eliminado: ASAN_16637.png
# Archivo eliminado: ASAN_16640.png
# Archivo eliminado: ASAN_16645.png
# Archivo eliminado: ASAN_16652.png
# Archivo eliminado: ASAN_16658.png
# Archivo eliminado: ASAN_16661.png
# Archivo eliminado: ASAN_16664.png
# Archivo eliminado: ASAN_16666.png
# Archivo eliminado: ASAN_16667.png
# Archivo eliminado: ASAN_16673.png
# Archivo eliminado: ASAN_16674.png
# Archivo eliminado: ASAN_16676.png
# Archivo eliminado: ASAN_16681.png
# Archivo eliminado: ASAN_16682.png
# Archivo eliminado: ASAN_9584.png
# Archivo eliminado: ASAN_9585.png
# Archivo eliminado: ASAN_9586.png
# Archivo eliminado: ASAN_9590.png
# Archivo eliminado: ASAN_9593.png
# Archivo eliminado: ASAN_9594.png
# Archivo eliminado: ASAN_9595.png
# Archivo eliminado: ASAN_9597.png
# Archivo eliminado: ASAN_9601.png
# Archivo eliminado: ASAN_9602.png
# Archivo eliminado: ASAN_9606.png
# Archivo eliminado: ASAN_9608.png
# Archivo eliminado: ASAN_9610.png
# Archivo eliminado: ASAN_9615.png
# Archivo eliminado: ASAN_9618.png
# Archivo eliminado: ASAN_9622.png
# Archivo eliminado: ASAN_9623.png
# Archivo eliminado: ASAN_9625.png
# Archivo eliminado: ASAN_9627.png
# Archivo eliminado: ASAN_9628.png
# Archivo eliminado: ASAN_9634.png
# Archivo eliminado: ASAN_9637.png
# Archivo eliminado: ASAN_9638.png
# Archivo eliminado: ASAN_9640.png
# Archivo eliminado: ASAN_9644.png
# Archivo eliminado: ASAN_9648.png
# Archivo eliminado: ASAN_9650.png
# Archivo eliminado: ASAN_9651.png
# Archivo eliminado: ASAN_9652.png
# Archivo eliminado: ASAN_9656.png
# Archivo eliminado: ASAN_9657.png
# Archivo eliminado: ASAN_9659.png
# Archivo eliminado: ASAN_9660.png
# Archivo eliminado: ASAN_9661.png
# Archivo eliminado: ASAN_9663.png
# Archivo eliminado: ASAN_9665.png
# Archivo eliminado: ASAN_9666.png
# Archivo eliminado: ASAN_9667.png
# Archivo eliminado: ASAN_9668.png
# Archivo eliminado: ASAN_9670.png
# Archivo eliminado: ASAN_9672.png
# Archivo eliminado: ASAN_9673.png
# Archivo eliminado: ASAN_9674.png
# Archivo eliminado: ASAN_9677.png
# Archivo eliminado: ASAN_9678.png
# Archivo eliminado: ASAN_9679.png
# Archivo eliminado: ASAN_9682.png
# Archivo eliminado: ASAN_9684.png
# Archivo eliminado: ASAN_9686.png
# Archivo eliminado: ASAN_9689.png
# Archivo eliminado: ASAN_9691.png
# Archivo eliminado: ASAN_9694.png
# Archivo eliminado: ASAN_9695.png
# Archivo eliminado: ASAN_9696.png
# Archivo eliminado: ASAN_9697.png
# Archivo eliminado: ASAN_9698.png
# Archivo eliminado: ASAN_9706.png
# Archivo eliminado: ASAN_9711.png
# Archivo eliminado: ASAN_9714.png
# Archivo eliminado: ASAN_9715.png
# Archivo eliminado: ASAN_9717.png
# Archivo eliminado: ASAN_9721.png
# Archivo eliminado: ASAN_9724.png
# Archivo eliminado: ASAN_9729.png
# Archivo eliminado: ASAN_9730.png
# Archivo eliminado: ASAN_9731.png
# Archivo eliminado: ASAN_9732.png
# Archivo eliminado: ASAN_9734.png
# Archivo eliminado: ASAN_9736.png
# Archivo eliminado: ASAN_9737.png
# Archivo eliminado: ASAN_9738.png
# Archivo eliminado: ASAN_9739.png
# Archivo eliminado: ASAN_9742.png
# Archivo eliminado: ASAN_9743.png
# Archivo eliminado: ASAN_9744.png
# Archivo eliminado: ASAN_9749.png
# Archivo eliminado: ASAN_9754.png
# Archivo eliminado: ASAN_9758.png
# Archivo eliminado: ASAN_9760.png
# Archivo eliminado: ASAN_9761.png
# Archivo eliminado: ASAN_9762.png
# Archivo eliminado: ASAN_9765.png
# Archivo eliminado: ASAN_9768.png
# Archivo eliminado: ASAN_9773.png
# Archivo eliminado: ASAN_9774.png
# Archivo eliminado: ASAN_9775.png
# Archivo eliminado: ASAN_9782.png
# Archivo eliminado: ASAN_9791.png
# Archivo eliminado: ASAN_9798.png
# Archivo eliminado: ASAN_9801.png
# Archivo eliminado: ASAN_9803.png
# Archivo eliminado: ASAN_9811.png
# Archivo eliminado: ASAN_9814.png
# Archivo eliminado: ASAN_9819.png
# Archivo eliminado: ASAN_9820.png
# Archivo eliminado: ASAN_9826.png
# Archivo eliminado: ASAN_9829.png
# Archivo eliminado: ASAN_9831.png
# Archivo eliminado: ASAN_9835.png
# Archivo eliminado: ASAN_9836.png
# Archivo eliminado: ASAN_9837.png
# Archivo eliminado: ASAN_9838.png
# Archivo eliminado: ASAN_9847.png
# Archivo eliminado: ASAN_9848.png
# Archivo eliminado: ASAN_9852.png
# Archivo eliminado: ASAN_9853.png
# Archivo eliminado: ASAN_9854.png
# Archivo eliminado: ASAN_9857.png
# Archivo eliminado: ASAN_9859.png
# Archivo eliminado: ASAN_9860.png
# Archivo eliminado: ASAN_9862.png
# Archivo eliminado: ASAN_9863.png
# Archivo eliminado: ASAN_9864.png
# Archivo eliminado: ASAN_9867.png
# Archivo eliminado: ASAN_9868.png
# Archivo eliminado: ASAN_9872.png
# Archivo eliminado: ASAN_9874.png
# Archivo eliminado: ASAN_9877.png
# Archivo eliminado: ASAN_9880.png
# Archivo eliminado: ASAN_9881.png
# Archivo eliminado: ASAN_9882.png
# Archivo eliminado: ASAN_9885.png
# Archivo eliminado: ASAN_9886.png
# Archivo eliminado: ASAN_9888.png
# Archivo eliminado: ASAN_9889.png
# Archivo eliminado: ASAN_9890.png
# Archivo eliminado: ASAN_9891.png
# Archivo eliminado: ASAN_9892.png
# Archivo eliminado: ASAN_9894.png
# Archivo eliminado: ASAN_9899.png
# Archivo eliminado: ASAN_9900.png
# Archivo eliminado: ASAN_9901.png
# Archivo eliminado: ASAN_9903.png
# Archivo eliminado: ASAN_9905.png
# Archivo eliminado: ASAN_9908.png
# Archivo eliminado: ASAN_9910.png
# Archivo eliminado: ASAN_9912.png
# Archivo eliminado: ASAN_9913.png
# Archivo eliminado: ASAN_9917.png
# Archivo eliminado: ASAN_9921.png
# Archivo eliminado: ASAN_9925.png
# Archivo eliminado: ASAN_9928.png
# Archivo eliminado: ASAN_9930.png
# Archivo eliminado: ASAN_9936.png
# Archivo eliminado: ASAN_9937.png
# Archivo eliminado: ASAN_9938.png
# Archivo eliminado: ASAN_9941.png
# Archivo eliminado: ASAN_9942.png
# Archivo eliminado: ASAN_9944.png
# Archivo eliminado: ASAN_9945.png
# Archivo eliminado: ASAN_9949.png
# Archivo eliminado: ASAN_9954.png
# Archivo eliminado: ASAN_9956.png
# Archivo eliminado: ASAN_9957.png
# Archivo eliminado: ASAN_9958.png
# Archivo eliminado: ASAN_9960.png
# Archivo eliminado: ASAN_9967.png
# Archivo eliminado: ASAN_9968.png
# Archivo eliminado: ASAN_9970.png
# Archivo eliminado: ASAN_9971.png
# Archivo eliminado: ASAN_9972.png
# Archivo eliminado: ASAN_9974.png
# Archivo eliminado: ASAN_9975.png
# Archivo eliminado: ASAN_9982.png
# Archivo eliminado: ASAN_9983.png
# Archivo eliminado: ASAN_9987.png
# Archivo eliminado: ASAN_9988.png
# Archivo eliminado: ASAN_9989.png
# Archivo eliminado: ASAN_9990.png
# Archivo eliminado: ASAN_9991.png
# Archivo eliminado: ASAN_9993.png
# Archivo eliminado: ASAN_9995.png
# Archivo eliminado: ASAN_9996.png
# Archivo eliminado: ASAN_9998.png
# Proceso completado.

# %%
# Obtenemos ASAN
# División en 80% train y 20% validación

df = pd.read_csv('trainSet.csv')

trainSet_lr = DataBlock(
    blocks=(ImageBlock, CategoryBlock),  # La entrada es un bloque de imagenes, y la salida, categorias
    get_items=get_image_files,  # Utilizamos el mñetodo get_image_files proporcionado en el Notebook
    splitter=RandomSplitter(valid_pct=0.2, seed=0),  # Establecida semilla 0
    get_y=label_func,  # Las etiquetas son especificadas como contenido del dataset en si
    item_tfms=[Resize(224, method='squish')],  # Redimensionado
).dataloaders("ESRGAN/LR/", bs=32)

# %%
mobilenet3 = timm.create_model('mobilenetv3_large_100', pretrained=True)
mobilenet_learner_lr = Learner(trainSet_lr, mobilenet3, loss_func=FocalLoss(), metrics=[accuracy, error_rate])
mobilenet_learner_lr.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# MobileNetV3 (Input shape: 32 x 3 x 224 x 224)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 16 x 112 x 112
# Conv2d                                    432        True
# Identity
# Hardswish
# Conv2d                                    144        True
# Identity
# ReLU
# Identity
# Conv2d                                    256        True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 64 x 112 x 112
# Conv2d                                    1024       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 64 x 56 x 56
# Conv2d                                    576        True
# Identity
# ReLU
# Identity
# ____________________________________________________________________________
#                      32 x 24 x 56 x 56
# Conv2d                                    1536       True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 72 x 56 x 56
# Conv2d                                    1728       True
# Identity
# ReLU
# Conv2d                                    648        True
# Identity
# ReLU
# Identity
# ____________________________________________________________________________
#                      32 x 24 x 56 x 56
# Conv2d                                    1728       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 72 x 56 x 56
# Conv2d                                    1728       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 72 x 28 x 28
# Conv2d                                    1800       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 24 x 1 x 1
# Conv2d                                    1752       True
# ReLU
# ____________________________________________________________________________
#                      32 x 72 x 1 x 1
# Conv2d                                    1800       True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    2880       True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 120 x 28 x 28
# Conv2d                                    4800       True
# Identity
# ReLU
# Conv2d                                    3000       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 32 x 1 x 1
# Conv2d                                    3872       True
# ReLU
# ____________________________________________________________________________
#                      32 x 120 x 1 x 1
# Conv2d                                    3960       True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    4800       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 120 x 28 x 28
# Conv2d                                    4800       True
# Identity
# ReLU
# Conv2d                                    3000       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      32 x 32 x 1 x 1
# Conv2d                                    3872       True
# ReLU
# ____________________________________________________________________________
#                      32 x 120 x 1 x 1
# Conv2d                                    3960       True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 40 x 28 x 28
# Conv2d                                    4800       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 240 x 28 x 28
# Conv2d                                    9600       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 240 x 14 x 14
# Conv2d                                    2160       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    19200      True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 200 x 14 x 14
# Conv2d                                    16000      True
# Identity
# Hardswish
# Conv2d                                    1800       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    16000      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 184 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Hardswish
# Conv2d                                    1656       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 184 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Hardswish
# Conv2d                                    1656       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      32 x 80 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 480 x 14 x 14
# Conv2d                                    38400      True
# Identity
# Hardswish
# Conv2d                                    4320       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 120 x 1 x 1
# Conv2d                                    57720      True
# ReLU
# ____________________________________________________________________________
#                      32 x 480 x 1 x 1
# Conv2d                                    58080      True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    53760      True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Hardswish
# Conv2d                                    6048       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 168 x 1 x 1
# Conv2d                                    113064     True
# ReLU
# ____________________________________________________________________________
#                      32 x 672 x 1 x 1
# Conv2d                                    113568     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 112 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 672 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 672 x 7 x 7
# Conv2d                                    16800      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 168 x 1 x 1
# Conv2d                                    113064     True
# ReLU
# ____________________________________________________________________________
#                      32 x 672 x 1 x 1
# Conv2d                                    113568     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 160 x 7 x 7
# Conv2d                                    107520     True
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# Conv2d                                    24000      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 240 x 1 x 1
# Conv2d                                    230640     True
# ReLU
# ____________________________________________________________________________
#                      32 x 960 x 1 x 1
# Conv2d                                    231360     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 160 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# Conv2d                                    24000      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 240 x 1 x 1
# Conv2d                                    230640     True
# ReLU
# ____________________________________________________________________________
#                      32 x 960 x 1 x 1
# Conv2d                                    231360     True
# Hardsigmoid
# ____________________________________________________________________________
#                      32 x 160 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      32 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      32 x 960 x 1 x 1
# AdaptiveAvgPool2d
# Identity
# ____________________________________________________________________________
#                      32 x 1280 x 1 x 1
# Conv2d                                    1230080    True
# Hardswish
# ____________________________________________________________________________
#                      32 x 1280
# Flatten
# ____________________________________________________________________________
#                      32 x 1000
# Linear                                    1281000    True
# ____________________________________________________________________________
#
# Total params: 5,458,632
# Total trainable params: 5,458,632
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001FDFAD0D120>
# Loss function: FocalLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
lrs = mobilenet_learner_lr.lr_find()
# Entrena las capas superiores
mobilenet_learner_lr.fine_tune(epochs=5, base_lr=lrs[0])

mobilenet_learner_lr.recorder.plot_metrics()  #Muestra las pérdidas, el accuracy y la tasa de error
# Descongela todas las capas
mobilenet_learner_lr.unfreeze()

# Encuentrar nuevo lr
lrs = mobilenet_learner_lr.lr_find()

mobilenet_learner_lr.fine_tune(epochs=10, base_lr=lrs[0])
mobilenet_learner_lr.recorder.plot_metrics()  #Muestra las pérdidas, el accuracy y la tasa de error
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.080337</td>
#       <td>0.800840</td>
#       <td>0.629870</td>
#       <td>0.370130</td>
#       <td>01:40</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.458483</td>
#       <td>0.694044</td>
#       <td>0.663337</td>
#       <td>0.336663</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.348350</td>
#       <td>0.613466</td>
#       <td>0.697802</td>
#       <td>0.302198</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.150148</td>
#       <td>0.592430</td>
#       <td>0.707792</td>
#       <td>0.292208</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.072389</td>
#       <td>0.591344</td>
#       <td>0.717283</td>
#       <td>0.282717</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.044515</td>
#       <td>0.587634</td>
#       <td>0.722278</td>
#       <td>0.277722</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.094072</td>
#       <td>0.710605</td>
#       <td>0.701299</td>
#       <td>0.298701</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.038564</td>
#       <td>0.618517</td>
#       <td>0.722777</td>
#       <td>0.277223</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.028198</td>
#       <td>0.626347</td>
#       <td>0.732767</td>
#       <td>0.267233</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.036368</td>
#       <td>0.666786</td>
#       <td>0.717283</td>
#       <td>0.282717</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021930</td>
#       <td>0.665651</td>
#       <td>0.735265</td>
#       <td>0.264735</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.014507</td>
#       <td>0.657431</td>
#       <td>0.732268</td>
#       <td>0.267732</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.008012</td>
#       <td>0.641819</td>
#       <td>0.744256</td>
#       <td>0.255744</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.006162</td>
#       <td>0.659059</td>
#       <td>0.744755</td>
#       <td>0.255245</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.008364</td>
#       <td>0.650244</td>
#       <td>0.742258</td>
#       <td>0.257742</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.004644</td>
#       <td>0.649524</td>
#       <td>0.748751</td>
#       <td>0.251249</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003171</td>
#       <td>0.653864</td>
#       <td>0.752248</td>
#       <td>0.247752</td>
#       <td>01:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(mobilenet_learner_lr, 1, trainSet.valid)

preds, targets = mobilenet_learner_lr.get_preds(ds_idx=1)  # ds_idx=1 para el conjunto de validación

y_true = targets.numpy()
y_pred = preds.argmax(dim=1).numpy()  # Convierte las probabilidades en etiquetas predichas
balanced_acc = balanced_accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"Balanced accuracy: {balanced_acc * 100:.4f}")
print(f"Precision: {prec * 100:.4f}")
print(f"F1 Score: {f1 * 100:.4f}")

from sklearn.metrics import classification_report

y_true = targets.numpy()
y_pred = preds.argmax(dim=1).numpy()  # Convierte las probabilidades en etiquetas predichas

report = classification_report(y_true, y_pred, target_names=trainSet_lr.vocab)
print(report)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Balanced accuracy: 69.9857
# Precision: 75.1969
# F1 Score: 74.9611
#                            precision    recall  f1-score   support
#
#         actinic_keratosis       0.52      0.65      0.58        72
#      basal_cell_carcinoma       0.77      0.69      0.73       131
#            dermatofibroma       0.83      0.80      0.82       137
#                hemangioma       0.88      0.85      0.86       307
# intraepithelial_carcinoma       0.59      0.40      0.48       108
#               lentigo_nos       0.80      0.80      0.80       142
#                  melanoma       0.77      0.65      0.70        88
#                     nevus       0.79      0.86      0.82       323
#        pyogenic_granuloma       0.69      0.56      0.62        43
#       seborreic_keratosis       0.63      0.60      0.62       166
#   squamous_cell_carcinoma       0.67      0.71      0.69       153
#                      wart       0.75      0.83      0.79       332
#
#                  accuracy                           0.75      2002
#                 macro avg       0.72      0.70      0.71      2002
#              weighted avg       0.75      0.75      0.75      2002

# %% [markdown]
#  ## Pruebas con 8 BATCH.
#  ### Imagen agrandada

# %%
# Obtenemos ASAN
# División en 80% train y 20% validación

df = pd.read_csv('trainSet.csv')

trainSet = DataBlock(
    blocks=(ImageBlock, CategoryBlock),  # La entrada es un bloque de imagenes, y la salida, categorias
    get_items=get_image_files,  # Utilizamos el mñetodo get_image_files proporcionado en el Notebook
    splitter=RandomSplitter(valid_pct=0.4, seed=0),  # Establecida semilla 0
    get_y=label_func,  # Las etiquetas son especificadas como contenido del dataset en si
    item_tfms=[Resize(224, method='squish')],  # Redimensionado
).dataloaders("ESRGAN/test/", bs=8)
trainSet.show_batch()  # shows a batch of images

# %%
mobilenet3 = timm.create_model('mobilenetv3_large_100', pretrained=True)
mobilenet_learner = Learner(trainSet, mobilenet3, loss_func=FocalLoss(), metrics=[accuracy, error_rate])
mobilenet_learner.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# MobileNetV3 (Input shape: 8 x 3 x 224 x 224)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      8 x 16 x 112 x 112
# Conv2d                                    432        True
# Identity
# Hardswish
# Conv2d                                    144        True
# Identity
# ReLU
# Identity
# Conv2d                                    256        True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 64 x 112 x 112
# Conv2d                                    1024       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      8 x 64 x 56 x 56
# Conv2d                                    576        True
# Identity
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 24 x 56 x 56
# Conv2d                                    1536       True
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 72 x 56 x 56
# Conv2d                                    1728       True
# Identity
# ReLU
# Conv2d                                    648        True
# Identity
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 24 x 56 x 56
# Conv2d                                    1728       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 72 x 56 x 56
# Conv2d                                    1728       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      8 x 72 x 28 x 28
# Conv2d                                    1800       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      8 x 24 x 1 x 1
# Conv2d                                    1752       True
# ReLU
# ____________________________________________________________________________
#                      8 x 72 x 1 x 1
# Conv2d                                    1800       True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 40 x 28 x 28
# Conv2d                                    2880       True
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 120 x 28 x 28
# Conv2d                                    4800       True
# Identity
# ReLU
# Conv2d                                    3000       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 1 x 1
# Conv2d                                    3872       True
# ReLU
# ____________________________________________________________________________
#                      8 x 120 x 1 x 1
# Conv2d                                    3960       True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 40 x 28 x 28
# Conv2d                                    4800       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 120 x 28 x 28
# Conv2d                                    4800       True
# Identity
# ReLU
# Conv2d                                    3000       True
# Identity
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 1 x 1
# Conv2d                                    3872       True
# ReLU
# ____________________________________________________________________________
#                      8 x 120 x 1 x 1
# Conv2d                                    3960       True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 40 x 28 x 28
# Conv2d                                    4800       True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 240 x 28 x 28
# Conv2d                                    9600       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 240 x 14 x 14
# Conv2d                                    2160       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      8 x 80 x 14 x 14
# Conv2d                                    19200      True
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 200 x 14 x 14
# Conv2d                                    16000      True
# Identity
# Hardswish
# Conv2d                                    1800       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      8 x 80 x 14 x 14
# Conv2d                                    16000      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 184 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Hardswish
# Conv2d                                    1656       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      8 x 80 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 184 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Hardswish
# Conv2d                                    1656       True
# Identity
# Hardswish
# Identity
# ____________________________________________________________________________
#                      8 x 80 x 14 x 14
# Conv2d                                    14720      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 480 x 14 x 14
# Conv2d                                    38400      True
# Identity
# Hardswish
# Conv2d                                    4320       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 120 x 1 x 1
# Conv2d                                    57720      True
# ReLU
# ____________________________________________________________________________
#                      8 x 480 x 1 x 1
# Conv2d                                    58080      True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 112 x 14 x 14
# Conv2d                                    53760      True
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 672 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Hardswish
# Conv2d                                    6048       True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 168 x 1 x 1
# Conv2d                                    113064     True
# ReLU
# ____________________________________________________________________________
#                      8 x 672 x 1 x 1
# Conv2d                                    113568     True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 112 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 672 x 14 x 14
# Conv2d                                    75264      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 672 x 7 x 7
# Conv2d                                    16800      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 168 x 1 x 1
# Conv2d                                    113064     True
# ReLU
# ____________________________________________________________________________
#                      8 x 672 x 1 x 1
# Conv2d                                    113568     True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 160 x 7 x 7
# Conv2d                                    107520     True
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# Conv2d                                    24000      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 240 x 1 x 1
# Conv2d                                    230640     True
# ReLU
# ____________________________________________________________________________
#                      8 x 960 x 1 x 1
# Conv2d                                    231360     True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 160 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# Conv2d                                    24000      True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 240 x 1 x 1
# Conv2d                                    230640     True
# ReLU
# ____________________________________________________________________________
#                      8 x 960 x 1 x 1
# Conv2d                                    231360     True
# Hardsigmoid
# ____________________________________________________________________________
#                      8 x 160 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Identity
# Identity
# ____________________________________________________________________________
#                      8 x 960 x 7 x 7
# Conv2d                                    153600     True
# Identity
# Hardswish
# ____________________________________________________________________________
#                      8 x 960 x 1 x 1
# AdaptiveAvgPool2d
# Identity
# ____________________________________________________________________________
#                      8 x 1280 x 1 x 1
# Conv2d                                    1230080    True
# Hardswish
# ____________________________________________________________________________
#                      8 x 1280
# Flatten
# ____________________________________________________________________________
#                      8 x 1000
# Linear                                    1281000    True
# ____________________________________________________________________________
#
# Total params: 5,458,632
# Total trainable params: 5,458,632
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001EDE3004CC0>
# Loss function: FocalLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
lrs = mobilenet_learner.lr_find()
# Entrena las capas superiores
mobilenet_learner.fine_tune(epochs=5, base_lr=lrs[0])

mobilenet_learner.recorder.plot_metrics()  #Muestra las pérdidas, el accuracy y la tasa de error
# Descongela todas las capas
mobilenet_learner.unfreeze()

# Encontrar nuevo lr
lrs = mobilenet_learner.lr_find()

mobilenet_learner.fine_tune(epochs=10,base_lr=lrs[0])
mobilenet_learner.recorder.plot_metrics()  #Muestra las pérdidas, el accuracy y la tasa de error
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.956775</td>
#       <td>0.887295</td>
#       <td>0.584166</td>
#       <td>0.415834</td>
#       <td>02:18</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.553643</td>
#       <td>0.643668</td>
#       <td>0.670330</td>
#       <td>0.329670</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.476240</td>
#       <td>0.596739</td>
#       <td>0.710789</td>
#       <td>0.289211</td>
#       <td>02:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.303091</td>
#       <td>0.619746</td>
#       <td>0.696054</td>
#       <td>0.303946</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.129804</td>
#       <td>0.564393</td>
#       <td>0.726274</td>
#       <td>0.273726</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.103043</td>
#       <td>0.554999</td>
#       <td>0.735015</td>
#       <td>0.264985</td>
#       <td>01:52</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.123724</td>
#       <td>0.605746</td>
#       <td>0.710789</td>
#       <td>0.289211</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.073305</td>
#       <td>0.569816</td>
#       <td>0.733017</td>
#       <td>0.266983</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.062235</td>
#       <td>0.546099</td>
#       <td>0.738012</td>
#       <td>0.261988</td>
#       <td>02:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.064945</td>
#       <td>0.600147</td>
#       <td>0.734266</td>
#       <td>0.265734</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.055396</td>
#       <td>0.607826</td>
#       <td>0.730519</td>
#       <td>0.269481</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.048670</td>
#       <td>0.613554</td>
#       <td>0.740260</td>
#       <td>0.259740</td>
#       <td>02:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.028491</td>
#       <td>0.615612</td>
#       <td>0.736014</td>
#       <td>0.263986</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.023672</td>
#       <td>0.610012</td>
#       <td>0.732268</td>
#       <td>0.267732</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.034406</td>
#       <td>0.623842</td>
#       <td>0.738512</td>
#       <td>0.261488</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.023352</td>
#       <td>0.608402</td>
#       <td>0.741009</td>
#       <td>0.258991</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.020872</td>
#       <td>0.625411</td>
#       <td>0.739261</td>
#       <td>0.260739</td>
#       <td>01:58</td>
#     </tr>
#   </tbody>
# </table>
